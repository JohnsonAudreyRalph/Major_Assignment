# %% [markdown]
# <h1> Bước 1: </h1> Cài đặt thư viện và chương trình

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import TimeSeriesSplit
from sklearn.metrics import r2_score, mean_absolute_error, mean_absolute_percentage_error
from keras.models import load_model, Sequential
from keras.callbacks import ModelCheckpoint
from keras.layers import LSTM, Dense
from keras.utils.vis_utils import plot_model
import pickle

# %% [markdown]
# <h1> Bước 2:</h1> Sử dụng, khai thác thông tin dữ liệu

# %%
data = pd.read_csv('Data.csv', na_values=['null'], index_col='Date', parse_dates=True)

# %%
print(f"Số lượng dữ liệu: {data.shape[0]}x{data.shape[1]}")
# Out:
# Số lượng dữ liệu: 3776x6

# %%
data.drop(["Adj Close"], axis=1, inplace=True)
data.head() # 5 dòng đầu
# Out:
#                 Open      High       Low     Close    Volume
# Date
# 2003-12-31  4.045714  4.091429  3.880714  3.906429  16801400
# 2004-01-02  4.107143  4.127857  3.842143  3.916429  50230600
# 2004-01-05  3.892857  4.061429  3.875000  3.992857  25207000
# 2004-01-06  3.946429  4.339286  3.937143  4.257857  52633000
# 2004-01-07  4.307143  4.470000  4.249286  4.445714  68432000

# %%
data.info() # Thông tin của từng cột dữ liệu
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3776 entries, 2003-12-31 to 2018-12-31
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Open    3776 non-null   float64
#  1   High    3776 non-null   float64
#  2   Low     3776 non-null   float64
#  3   Close   3776 non-null   float64
#  4   Volume  3776 non-null   int64
# dtypes: float64(4), int64(1)
# memory usage: 177.0 KB

# %%
data.describe() # Thông tin từng cột dữ liệu
# Out:
#               Open         High          Low        Close        Volume
# count  3776.000000  3776.000000  3776.000000  3776.000000  3.776000e+03
# mean     56.653638    57.552998    55.681395    56.643953  1.918587e+07
# std      85.461244    86.790599    83.904099    85.372837  2.074758e+07
# min       1.300000     1.317143     1.272857     1.290000  1.493800e+06
# 25%       4.082857     4.156786     3.992857     4.094286  7.792225e+06
# 50%      15.432143    15.760714    15.046429    15.395000  1.297695e+07
# 75%      68.606428    69.155716    67.800713    68.397860  2.287355e+07
# max     421.380005   423.209991   413.079987   418.970001  3.234140e+08

# %% [markdown]
# <h3> Tính tỷ suất lợi nhuận </h3>

# %%
Profit_Margin = pd.DataFrame() # DataFrame này có tác dụng dùng để chứa giá trị tỷ suất lợi nhuận cho từng ngày
Profit_Margin['Profit_Margin__Open'] = data['Open'].pct_change()
Profit_Margin['Profit_Margin__High'] = data['High'].pct_change()
Profit_Margin['Profit_Margin__Low'] = data['Low'].pct_change()
Profit_Margin['Profit_Margin__Close'] = data['Close'].pct_change()
Profit_Margin['Profit_Margin__Volume'] = data['Volume'].pct_change()
Profit_Margin = Profit_Margin.dropna()
Profit_Margin.head()
# Out:
#             Profit_Margin__Open  Profit_Margin__High  Profit_Margin__Low
# Date
# 2004-01-02             0.015184             0.008903           -0.009939  \
# 2004-01-05            -0.052174            -0.016093            0.008552
# 2004-01-06             0.013762             0.068414            0.016037
# 2004-01-07             0.091403             0.030123            0.079282
# 2004-01-08             0.053897             0.021093            0.009918
#
#             Profit_Margin__Close  Profit_Margin__Volume
# Date
# 2004-01-02              0.002560               1.989668
# 2004-01-05              0.019515              -0.498174
# 2004-01-06              0.066369               1.088031
# 2004-01-07              0.044120               0.300173
# 2004-01-08             -0.002892              -0.456710

# %% [markdown]
# <h3>Trực quan hóa dữ liệu</h3>

# %%
fig, axs = plt.subplots(4, 1, figsize=(15, 10))

# Biểu đồ giá mở cửa
axs[0].plot(data['Open'], color="red")
axs[0].set_ylabel("Giá mở cửa")
axs[0].grid(color='green', linestyle='--', linewidth=0.5)

# Biểu đồ giá cao nhất
axs[1].plot(data['High'], color="purple")
axs[1].set_ylabel("Giá cao nhất")
axs[1].grid(color='green', linestyle='--', linewidth=0.5)

# Biểu đồ giá thấp nhất
axs[2].plot(data['Low'], color="orange")
axs[2].set_ylabel("Giá thấp nhất")
axs[2].grid(color='green', linestyle='--', linewidth=0.5)

# Biểu đồ giá đóng cửa
axs[3].plot(data['Close'], color="yellow")
axs[3].set_ylabel("Giá đóng cửa")
axs[3].grid(color='green', linestyle='--', linewidth=0.5)

# Đặt tiêu đề chung cho biểu đồ
fig.suptitle("Biểu đồ giá chứng khoán")

# Định dạng đồ thị
plt.xlabel("Thời gian")
plt.tight_layout()

# Hiển thị biểu đồ
plt.show()

# %%
features = ['Open', 'High', 'Low', 'Close', 'Volume']
fig, axes = plt.subplots(2, 3, figsize=(20, 10))
for i, col in enumerate(features):
    sb.histplot(data[col], ax=axes[i // 3, i % 3])
plt.show()

# %%
fig, axes = plt.subplots(2, 3, figsize=(20, 10))
for i, col in enumerate(features):
    sb.boxplot(data[col], ax=axes[i // 3, i % 3])
plt.show()

# %% [markdown]
# <h1> Bước 3:</h1> Sử dụng dữ liệu để thực hiện huấn luyện cho mô hình

# %% [markdown]
# <li>Sử dụng thông tin dữ liệu của giá 'High', 'Low', 'Close' và 'Volume' để dự đoán giá 'Open'</li>

# %%
features_Open = ["High", "Low", "Close", "Volume"]
output_var_Open = pd.DataFrame(data["Open"])

scaler_Open = MinMaxScaler(feature_range=(0, 1))
feature_transform_Open = scaler_Open.fit_transform(data[features_Open])
feature_transform_Open = pd.DataFrame(columns=features_Open, data=feature_transform_Open, index=data.index)

# %%
# Chia tập dữ liệu thành các tập train và test
timesplit = TimeSeriesSplit(n_splits=10)
for train_index_Open, test_index_Open in timesplit.split(feature_transform_Open):
    X_train_Open, X_test_Open = feature_transform_Open[:len(train_index_Open)], feature_transform_Open[len(train_index_Open): (len(train_index_Open)+len(test_index_Open))]
    y_train_Open, y_test_Open = output_var_Open[1:len(train_index_Open)+1].values.ravel(), output_var_Open[len(train_index_Open)+1: (len(train_index_Open)+len(test_index_Open)+1)].values.ravel()
    X_test_Open = X_test_Open[:-1]

# %%
# Chuyển đổi dữ liệu thành dạng phù hợp cho LSTM
trainX_Open = np.array(X_train_Open)
testX_Open = np.array(X_test_Open)
X_train_Open = trainX_Open.reshape(X_train_Open.shape[0], 1, X_train_Open.shape[1])
X_test_Open = testX_Open.reshape(X_test_Open.shape[0], 1, X_test_Open.shape[1])

# %%
# Xây dựng mô hình LSTM
model = Sequential()
model.add(LSTM(32, input_shape=(X_train_Open.shape[1], X_train_Open.shape[2]), activation="relu", return_sequences=True))
model.add(LSTM(32, activation="relu"))
model.add(Dense(1))
model.compile(loss="mean_squared_error", optimizer="adam")
plot_model(model, show_shapes=True, show_layer_names=True)

# %%
# Huấn luyện mô hình
save_model = 'Models/Model/Model_Open.h5'
plot_model(model, show_shapes=True, show_layer_names=True)
best_model = ModelCheckpoint(save_model, monitor='loss', verbose=1, save_best_only=True, mode='auto')
model.fit(X_train_Open, y_train_Open, epochs=100, batch_size=8, verbose=1, callbacks=[best_model])
# Out:
# Epoch 1/100
# 429/430 [============================>.] - ETA: 0s - loss: 1950.3439
# Epoch 1: loss improved from inf to 1949.88892, saving model to Models/Model\Model_Open.h5
# 430/430 [==============================] - 3s 2ms/step - loss: 1949.8889
# Epoch 2/100
# 418/430 [============================>.] - ETA: 0s - loss: 214.1293
# Epoch 2: loss improved from 1949.88892 to 210.33119, saving model to Models/Model\Model_Open.h5
# 430/430 [==============================] - 1s 2ms/step - loss: 210.3312
# Epoch 3/100
# 412/430 [===========================>..] - ETA: 0s - loss: 47.3106
# Epoch 3: loss improved from 210.33119 to 46.69544, saving model to Models/Model\Model_Open.h5
# 430/430 [==============================] - 1s 2ms/step - loss: 46.6954
# Epoch 4/100
# 418/430 [============================>.] - ETA: 0s - loss: 23.9081
# Epoch 4: loss improved from 46.69544 to 23.73064, saving model to Models/Model\Model_Open.h5
# 430/430 [==============================] - 1s 2ms/step - loss: 23.7306
# Epoch 5/100
# 419/430 [============================>.] - ETA: 0s - loss: 13.4146
# Epoch 5: loss improved from 23.73064 to 13.32199, saving model to Models/Model\Model_Open.h5
# 430/430 [==============================] - 1s 2ms/step - loss: 13.3220
# Epoch 6/100
# 424/430 [============================>.] - ETA: 0s - loss: 7.9409
# Epoch 6: loss improved from 13.32199 to 7.90102, saving model to Models/Model\Model_Open.h5
# 430/430 [==============================] - 1s 2ms/step - loss: 7.9010
# Epoch 7/100
# 429/430 [============================>.] - ETA: 0s - loss: 4.9668
# Epoch 7: loss improved from 7.90102 to 4.96558, saving model to Models/Model\Model_Open.h5
# 430/430 [==============================] - 1s 2ms/step - loss: 4.9656
# Epoch 8/100
# 430/430 [==============================] - ETA: 0s - loss: 3.3748
# Epoch 8: loss improved from 4.96558 to 3.37484, saving model to Models/Model\Model_Open.h5
# 430/430 [==============================] - 1s 2ms/step - loss: 3.3748
# Epoch 9/100
# 411/430 [===========================>..] - ETA: 0s - loss: 2.5454
# Epoch 9: loss improved from 3.37484 to 2.56393, saving model to Models/Model\Model_Open.h5
# 430/430 [==============================] - 1s 2ms/step - loss: 2.5639
# Epoch 10/100
# 399/430 [==========================>...] - ETA: 0s - loss: 2.0824
# Epoch 10: loss improved from 2.56393 to 2.11625, saving model to Models/Model\Model_Open.h5
# 430/430 [==============================] - 1s 2ms/step - loss: 2.1162
# Epoch 11/100
# 423/430 [============================>.] - ETA: 0s - loss: 1.8278
# Epoch 11: loss improved from 2.11625 to 1.90522, saving model to Models/Model\Model_Open.h5
# 430/430 [==============================] - 1s 2ms/step - loss: 1.9052
# Epoch 12/100
# 400/430 [==========================>...] - ETA: 0s - loss: 1.8799
# Epoch 12: loss improved from 1.90522 to 1.82363, saving model to Models/Model\Model_Open.h5
# 430/430 [==============================] - 1s 2ms/step - loss: 1.8236
# Epoch 13/100
# 397/430 [==========================>...] - ETA: 0s - loss: 1.7846
# Epoch 13: loss improved from 1.82363 to 1.78561, saving model to Models/Model\Model_Open.h5
# 430/430 [==============================] - 1s 2ms/step - loss: 1.7856
# Epoch 14/100
# 429/430 [============================>.] - ETA: 0s - loss: 1.7806
# Epoch 14: loss improved from 1.78561 to 1.78048, saving model to Models/Model\Model_Open.h5
# 430/430 [==============================] - 1s 2ms/step - loss: 1.7805
# Epoch 15/100
# 398/430 [==========================>...] - ETA: 0s - loss: 1.7403
# Epoch 15: loss improved from 1.78048 to 1.72961, saving model to Models/Model\Model_Open.h5
# 430/430 [==============================] - 1s 2ms/step - loss: 1.7296
# Epoch 16/100
# 430/430 [==============================] - ETA: 0s - loss: 1.7749
# Epoch 16: loss did not improve from 1.72961
# 430/430 [==============================] - 1s 2ms/step - loss: 1.7749
# Epoch 17/100
# 412/430 [===========================>..] - ETA: 0s - loss: 1.7319
# Epoch 17: loss improved from 1.72961 to 1.69732, saving model to Models/Model\Model_Open.h5
# 430/430 [==============================] - 1s 2ms/step - loss: 1.6973
# Epoch 18/100
# 427/430 [============================>.] - ETA: 0s - loss: 1.7218
# Epoch 18: loss did not improve from 1.69732
# 430/430 [==============================] - 1s 2ms/step - loss: 1.7158
# Epoch 19/100
# 429/430 [============================>.] - ETA: 0s - loss: 1.6953
# Epoch 19: loss improved from 1.69732 to 1.69478, saving model to Models/Model\Model_Open.h5
# 430/430 [==============================] - 1s 2ms/step - loss: 1.6948
# Epoch 20/100
# 430/430 [==============================] - ETA: 0s - loss: 1.6543
# Epoch 20: loss improved from 1.69478 to 1.65426, saving model to Models/Model\Model_Open.h5
# 430/430 [==============================] - 1s 2ms/step - loss: 1.6543
# Epoch 21/100
# 405/430 [===========================>..] - ETA: 0s - loss: 1.6344
# Epoch 21: loss did not improve from 1.65426
# 430/430 [==============================] - 1s 2ms/step - loss: 1.7011
# Epoch 22/100
# 425/430 [============================>.] - ETA: 0s - loss: 1.6275
# Epoch 22: loss improved from 1.65426 to 1.62296, saving model to Models/Model\Model_Open.h5
# 430/430 [==============================] - 1s 2ms/step - loss: 1.6230
# Epoch 23/100
# 404/430 [===========================>..] - ETA: 0s - loss: 1.6865
# Epoch 23: loss did not improve from 1.62296
# 430/430 [==============================] - 1s 2ms/step - loss: 1.6337
# Epoch 24/100
# 409/430 [===========================>..] - ETA: 0s - loss: 1.5332
# Epoch 24: loss improved from 1.62296 to 1.53321, saving model to Models/Model\Model_Open.h5
# 430/430 [==============================] - 1s 2ms/step - loss: 1.5332
# Epoch 25/100
# 404/430 [===========================>..] - ETA: 0s - loss: 1.4168
# Epoch 25: loss improved from 1.53321 to 1.47111, saving model to Models/Model\Model_Open.h5
# 430/430 [==============================] - 1s 2ms/step - loss: 1.4711
# Epoch 26/100
# 407/430 [===========================>..] - ETA: 0s - loss: 1.4580
# Epoch 26: loss improved from 1.47111 to 1.42080, saving model to Models/Model\Model_Open.h5
# 430/430 [==============================] - 1s 2ms/step - loss: 1.4208
# Epoch 27/100
# 430/430 [==============================] - ETA: 0s - loss: 1.4330
# Epoch 27: loss did not improve from 1.42080
# 430/430 [==============================] - 1s 2ms/step - loss: 1.4330
# Epoch 28/100
# 430/430 [==============================] - ETA: 0s - loss: 1.3697
# Epoch 28: loss improved from 1.42080 to 1.36974, saving model to Models/Model\Model_Open.h5
# 430/430 [==============================] - 1s 2ms/step - loss: 1.3697
# Epoch 29/100
# 427/430 [============================>.] - ETA: 0s - loss: 1.3850
# Epoch 29: loss did not improve from 1.36974
# 430/430 [==============================] - 1s 2ms/step - loss: 1.3810
# Epoch 30/100
# 397/430 [==========================>...] - ETA: 0s - loss: 1.3405
# Epoch 30: loss improved from 1.36974 to 1.31194, saving model to Models/Model\Model_Open.h5
# 430/430 [==============================] - 1s 2ms/step - loss: 1.3119
# Epoch 31/100
# 405/430 [===========================>..] - ETA: 0s - loss: 1.3233
# Epoch 31: loss did not improve from 1.31194
# 430/430 [==============================] - 1s 2ms/step - loss: 1.3538
# Epoch 32/100
# 407/430 [===========================>..] - ETA: 0s - loss: 1.3531
# Epoch 32: loss did not improve from 1.31194
# 430/430 [==============================] - 1s 2ms/step - loss: 1.3207
# Epoch 33/100
# 428/430 [============================>.] - ETA: 0s - loss: 1.3003
# Epoch 33: loss improved from 1.31194 to 1.30011, saving model to Models/Model\Model_Open.h5
# 430/430 [==============================] - 1s 2ms/step - loss: 1.3001
# Epoch 34/100
# 398/430 [==========================>...] - ETA: 0s - loss: 1.3208
# Epoch 34: loss improved from 1.30011 to 1.29271, saving model to Models/Model\Model_Open.h5
# 430/430 [==============================] - 1s 2ms/step - loss: 1.2927
# Epoch 35/100
# 430/430 [==============================] - ETA: 0s - loss: 1.2902
# Epoch 35: loss improved from 1.29271 to 1.29023, saving model to Models/Model\Model_Open.h5
# 430/430 [==============================] - 1s 2ms/step - loss: 1.2902
# Epoch 36/100
# 399/430 [==========================>...] - ETA: 0s - loss: 1.3935
# Epoch 36: loss did not improve from 1.29023
# 430/430 [==============================] - 1s 2ms/step - loss: 1.3374
# Epoch 37/100
# 430/430 [==============================] - ETA: 0s - loss: 1.2265
# Epoch 37: loss improved from 1.29023 to 1.22650, saving model to Models/Model\Model_Open.h5
# 430/430 [==============================] - 1s 2ms/step - loss: 1.2265
# Epoch 38/100
# 399/430 [==========================>...] - ETA: 0s - loss: 1.4157
# Epoch 38: loss did not improve from 1.22650
# 430/430 [==============================] - 1s 2ms/step - loss: 1.3465
# Epoch 39/100
# 403/430 [===========================>..] - ETA: 0s - loss: 1.2422
# Epoch 39: loss did not improve from 1.22650
# 430/430 [==============================] - 1s 2ms/step - loss: 1.2381
# Epoch 40/100
# 400/430 [==========================>...] - ETA: 0s - loss: 1.2749
# Epoch 40: loss did not improve from 1.22650
# 430/430 [==============================] - 1s 2ms/step - loss: 1.3000
# Epoch 41/100
# 410/430 [===========================>..] - ETA: 0s - loss: 1.2137
# Epoch 41: loss improved from 1.22650 to 1.21615, saving model to Models/Model\Model_Open.h5
# 430/430 [==============================] - 1s 2ms/step - loss: 1.2162
# Epoch 42/100
# 430/430 [==============================] - ETA: 0s - loss: 1.2081
# Epoch 42: loss improved from 1.21615 to 1.20809, saving model to Models/Model\Model_Open.h5
# 430/430 [==============================] - 1s 2ms/step - loss: 1.2081
# Epoch 43/100
# 429/430 [============================>.] - ETA: 0s - loss: 1.2715
# Epoch 43: loss did not improve from 1.20809
# 430/430 [==============================] - 1s 2ms/step - loss: 1.2711
# Epoch 44/100
# 401/430 [==========================>...] - ETA: 0s - loss: 1.2819
# Epoch 44: loss did not improve from 1.20809
# 430/430 [==============================] - 1s 2ms/step - loss: 1.2318
# Epoch 45/100
# 398/430 [==========================>...] - ETA: 0s - loss: 1.2150
# Epoch 45: loss did not improve from 1.20809
# 430/430 [==============================] - 1s 2ms/step - loss: 1.2116
# Epoch 46/100
# 401/430 [==========================>...] - ETA: 0s - loss: 1.2055
# Epoch 46: loss improved from 1.20809 to 1.18933, saving model to Models/Model\Model_Open.h5
# 430/430 [==============================] - 1s 2ms/step - loss: 1.1893
# Epoch 47/100
# 418/430 [============================>.] - ETA: 0s - loss: 1.3324
# Epoch 47: loss did not improve from 1.18933
# 430/430 [==============================] - 1s 2ms/step - loss: 1.3081
# Epoch 48/100
# 428/430 [============================>.] - ETA: 0s - loss: 1.2722
# Epoch 48: loss did not improve from 1.18933
# 430/430 [==============================] - 1s 2ms/step - loss: 1.2701
# Epoch 49/100
# 428/430 [============================>.] - ETA: 0s - loss: 1.1954
# Epoch 49: loss did not improve from 1.18933
# 430/430 [==============================] - 1s 2ms/step - loss: 1.1929
# Epoch 50/100
# 426/430 [============================>.] - ETA: 0s - loss: 1.2459
# Epoch 50: loss did not improve from 1.18933
# 430/430 [==============================] - 1s 2ms/step - loss: 1.2387
# Epoch 51/100
# 410/430 [===========================>..] - ETA: 0s - loss: 1.2257
# Epoch 51: loss did not improve from 1.18933
# 430/430 [==============================] - 1s 2ms/step - loss: 1.2247
# Epoch 52/100
# 409/430 [===========================>..] - ETA: 0s - loss: 1.3138
# Epoch 52: loss did not improve from 1.18933
# 430/430 [==============================] - 1s 2ms/step - loss: 1.2750
# Epoch 53/100
# 412/430 [===========================>..] - ETA: 0s - loss: 1.2401
# Epoch 53: loss did not improve from 1.18933
# 430/430 [==============================] - 1s 2ms/step - loss: 1.2064
# Epoch 54/100
# 412/430 [===========================>..] - ETA: 0s - loss: 1.2787
# Epoch 54: loss did not improve from 1.18933
# 430/430 [==============================] - 1s 2ms/step - loss: 1.2409
# Epoch 55/100
# 409/430 [===========================>..] - ETA: 0s - loss: 1.2338
# Epoch 55: loss did not improve from 1.18933
# 430/430 [==============================] - 1s 2ms/step - loss: 1.2911
# Epoch 56/100
# 413/430 [===========================>..] - ETA: 0s - loss: 1.2100
# Epoch 56: loss did not improve from 1.18933
# 430/430 [==============================] - 1s 2ms/step - loss: 1.2683
# Epoch 57/100
# 403/430 [===========================>..] - ETA: 0s - loss: 1.2903
# Epoch 57: loss did not improve from 1.18933
# 430/430 [==============================] - 1s 2ms/step - loss: 1.2371
# Epoch 58/100
# 419/430 [============================>.] - ETA: 0s - loss: 1.2088
# Epoch 58: loss did not improve from 1.18933
# 430/430 [==============================] - 1s 2ms/step - loss: 1.2204
# Epoch 59/100
# 411/430 [===========================>..] - ETA: 0s - loss: 1.3286
# Epoch 59: loss did not improve from 1.18933
# 430/430 [==============================] - 1s 2ms/step - loss: 1.3120
# Epoch 60/100
# 425/430 [============================>.] - ETA: 0s - loss: 1.2077
# Epoch 60: loss did not improve from 1.18933
# 430/430 [==============================] - 1s 2ms/step - loss: 1.2064
# Epoch 61/100
# 416/430 [============================>.] - ETA: 0s - loss: 1.2806
# Epoch 61: loss did not improve from 1.18933
# 430/430 [==============================] - 1s 2ms/step - loss: 1.3039
# Epoch 62/100
# 419/430 [============================>.] - ETA: 0s - loss: 1.2367
# Epoch 62: loss did not improve from 1.18933
# 430/430 [==============================] - 1s 2ms/step - loss: 1.2362
# Epoch 63/100
# 416/430 [============================>.] - ETA: 0s - loss: 1.3038
# Epoch 63: loss did not improve from 1.18933
# 430/430 [==============================] - 1s 2ms/step - loss: 1.2727
# Epoch 64/100
# 428/430 [============================>.] - ETA: 0s - loss: 1.1978
# Epoch 64: loss did not improve from 1.18933
# 430/430 [==============================] - 1s 2ms/step - loss: 1.2378
# Epoch 65/100
# 430/430 [==============================] - ETA: 0s - loss: 1.3076
# Epoch 65: loss did not improve from 1.18933
# 430/430 [==============================] - 1s 2ms/step - loss: 1.3076
# Epoch 66/100
# 413/430 [===========================>..] - ETA: 0s - loss: 1.1844
# Epoch 66: loss did not improve from 1.18933
# 430/430 [==============================] - 1s 1ms/step - loss: 1.2122
# Epoch 67/100
# 403/430 [===========================>..] - ETA: 0s - loss: 1.2444
# Epoch 67: loss did not improve from 1.18933
# 430/430 [==============================] - 1s 2ms/step - loss: 1.2010
# Epoch 68/100
# 413/430 [===========================>..] - ETA: 0s - loss: 1.2581
# Epoch 68: loss did not improve from 1.18933
# 430/430 [==============================] - 1s 2ms/step - loss: 1.2329
# Epoch 69/100
# 421/430 [============================>.] - ETA: 0s - loss: 1.2270
# Epoch 69: loss did not improve from 1.18933
# 430/430 [==============================] - 1s 2ms/step - loss: 1.2401
# Epoch 70/100
# 430/430 [==============================] - ETA: 0s - loss: 1.1951
# Epoch 70: loss did not improve from 1.18933
# 430/430 [==============================] - 1s 2ms/step - loss: 1.1951
# Epoch 71/100
# 410/430 [===========================>..] - ETA: 0s - loss: 1.2083
# Epoch 71: loss did not improve from 1.18933
# 430/430 [==============================] - 1s 1ms/step - loss: 1.2293
# Epoch 72/100
# 415/430 [===========================>..] - ETA: 0s - loss: 1.2341
# Epoch 72: loss did not improve from 1.18933
# 430/430 [==============================] - 1s 1ms/step - loss: 1.2329
# Epoch 73/100
# 414/430 [===========================>..] - ETA: 0s - loss: 1.2031
# Epoch 73: loss did not improve from 1.18933
# 430/430 [==============================] - 1s 1ms/step - loss: 1.1963
# Epoch 74/100
# 410/430 [===========================>..] - ETA: 0s - loss: 1.2338
# Epoch 74: loss did not improve from 1.18933
# 430/430 [==============================] - 1s 2ms/step - loss: 1.2093
# Epoch 75/100
# 409/430 [===========================>..] - ETA: 0s - loss: 1.2421
# Epoch 75: loss did not improve from 1.18933
# 430/430 [==============================] - 1s 1ms/step - loss: 1.2683
# Epoch 76/100
# 430/430 [==============================] - ETA: 0s - loss: 1.2620
# Epoch 76: loss did not improve from 1.18933
# 430/430 [==============================] - 1s 1ms/step - loss: 1.2620
# Epoch 77/100
# 420/430 [============================>.] - ETA: 0s - loss: 1.2597
# Epoch 77: loss did not improve from 1.18933
# 430/430 [==============================] - 1s 1ms/step - loss: 1.2560
# Epoch 78/100
# 429/430 [============================>.] - ETA: 0s - loss: 1.2035
# Epoch 78: loss did not improve from 1.18933
# 430/430 [==============================] - 1s 2ms/step - loss: 1.2032
# Epoch 79/100
# 430/430 [==============================] - ETA: 0s - loss: 1.2541
# Epoch 79: loss did not improve from 1.18933
# 430/430 [==============================] - 1s 2ms/step - loss: 1.2541
# Epoch 80/100
# 404/430 [===========================>..] - ETA: 0s - loss: 1.2248
# Epoch 80: loss improved from 1.18933 to 1.18095, saving model to Models/Model\Model_Open.h5
# 430/430 [==============================] - 1s 2ms/step - loss: 1.1809
# Epoch 81/100
# 416/430 [============================>.] - ETA: 0s - loss: 1.2275
# Epoch 81: loss did not improve from 1.18095
# 430/430 [==============================] - 1s 2ms/step - loss: 1.2009
# Epoch 82/100
# 409/430 [===========================>..] - ETA: 0s - loss: 1.2805
# Epoch 82: loss did not improve from 1.18095
# 430/430 [==============================] - 1s 2ms/step - loss: 1.2566
# Epoch 83/100
# 418/430 [============================>.] - ETA: 0s - loss: 1.2513
# Epoch 83: loss did not improve from 1.18095
# 430/430 [==============================] - 1s 2ms/step - loss: 1.2288
# Epoch 84/100
# 414/430 [===========================>..] - ETA: 0s - loss: 1.1639
# Epoch 84: loss did not improve from 1.18095
# 430/430 [==============================] - 1s 2ms/step - loss: 1.1994
# Epoch 85/100
# 398/430 [==========================>...] - ETA: 0s - loss: 1.2668
# Epoch 85: loss did not improve from 1.18095
# 430/430 [==============================] - 1s 2ms/step - loss: 1.2432
# Epoch 86/100
# 426/430 [============================>.] - ETA: 0s - loss: 1.1853
# Epoch 86: loss improved from 1.18095 to 1.18009, saving model to Models/Model\Model_Open.h5
# 430/430 [==============================] - 1s 2ms/step - loss: 1.1801
# Epoch 87/100
# 406/430 [===========================>..] - ETA: 0s - loss: 1.1346
# Epoch 87: loss did not improve from 1.18009
# 430/430 [==============================] - 1s 1ms/step - loss: 1.1999
# Epoch 88/100
# 424/430 [============================>.] - ETA: 0s - loss: 1.2814
# Epoch 88: loss did not improve from 1.18009
# 430/430 [==============================] - 1s 1ms/step - loss: 1.2729
# Epoch 89/100
# 395/430 [==========================>...] - ETA: 0s - loss: 1.2277
# Epoch 89: loss did not improve from 1.18009
# 430/430 [==============================] - 1s 1ms/step - loss: 1.2224
# Epoch 90/100
# 408/430 [===========================>..] - ETA: 0s - loss: 1.1779
# Epoch 90: loss did not improve from 1.18009
# 430/430 [==============================] - 1s 2ms/step - loss: 1.2268
# Epoch 91/100
# 421/430 [============================>.] - ETA: 0s - loss: 1.2026
# Epoch 91: loss did not improve from 1.18009
# 430/430 [==============================] - 1s 1ms/step - loss: 1.2019
# Epoch 92/100
# 394/430 [==========================>...] - ETA: 0s - loss: 1.2712
# Epoch 92: loss did not improve from 1.18009
# 430/430 [==============================] - 1s 1ms/step - loss: 1.2384
# Epoch 93/100
# 405/430 [===========================>..] - ETA: 0s - loss: 1.2708
# Epoch 93: loss did not improve from 1.18009
# 430/430 [==============================] - 1s 2ms/step - loss: 1.2490
# Epoch 94/100
# 393/430 [==========================>...] - ETA: 0s - loss: 1.1746
# Epoch 94: loss did not improve from 1.18009
# 430/430 [==============================] - 1s 2ms/step - loss: 1.2641
# Epoch 95/100
# 404/430 [===========================>..] - ETA: 0s - loss: 1.2578
# Epoch 95: loss did not improve from 1.18009
# 430/430 [==============================] - 1s 1ms/step - loss: 1.2414
# Epoch 96/100
# 421/430 [============================>.] - ETA: 0s - loss: 1.2367
# Epoch 96: loss did not improve from 1.18009
# 430/430 [==============================] - 1s 2ms/step - loss: 1.2280
# Epoch 97/100
# 411/430 [===========================>..] - ETA: 0s - loss: 1.1946
# Epoch 97: loss did not improve from 1.18009
# 430/430 [==============================] - 1s 1ms/step - loss: 1.2182
# Epoch 98/100
# 400/430 [==========================>...] - ETA: 0s - loss: 1.1936
# Epoch 98: loss did not improve from 1.18009
# 430/430 [==============================] - 1s 1ms/step - loss: 1.1930
# Epoch 99/100
# 417/430 [============================>.] - ETA: 0s - loss: 1.1802
# Epoch 99: loss did not improve from 1.18009
# 430/430 [==============================] - 1s 1ms/step - loss: 1.1915
# Epoch 100/100
# 430/430 [==============================] - ETA: 0s - loss: 1.2340
# Epoch 100: loss did not improve from 1.18009
# 430/430 [==============================] - 1s 1ms/step - loss: 1.2340

# %%
with open('Models/scaler/scaler_Open.pkl', 'wb') as file:
    pickle.dump(scaler_Open, file)

# %%
# Đánh giá độ chính xác trên tập kiểm tra
loss = model.evaluate(X_test_Open, y_test_Open, verbose=0)
print("Kết quả (MSE):", loss) # Lỗi bình phương trung bình trên bộ TEST
y_pred_Open = model.predict(X_test_Open)
r2 = r2_score(y_test_Open, y_pred_Open)
mae = mean_absolute_error(y_test_Open, y_pred_Open)
mape = mean_absolute_percentage_error(y_test_Open, y_pred_Open)

print("R₂: ", r2) # Độ chính xác của tập Train (R2 Score)
print("MAE: ", mae) # Sai số tuyệt đối trung bình của tập Train (Mean Absolute Error)
print("MAPE: ", mape , "%") # Phần trăm sai số tuyệt đối trung bình của tập Train (Mean Absolute Percentage Error)

# Vẽ biểu đồ đánh giá độ chính xác
plt.figure(figsize=(10, 6))
plt.plot(y_test_Open, label='Actual')
plt.plot(y_pred_Open, label='Predicted')
plt.title('Biểu đồ đánh giá độ chính xác của quá trình huấn luyện dự đoán giá mở cửa')
plt.legend()
plt.show()
# Out:
# Kết quả (MSE): 229.70106506347656
# 11/11 [==============================] - 0s 2ms/step
# R₂:  0.9556664320110589
# MAE:  11.654222227970235
# MAPE:  0.03619708509598458 %

# %% [markdown]
# <li>Sử dụng thông tin dữ liệu của giá 'Open', 'Low', 'Close' và 'Volume' để dự đoán giá 'High'</li>

# %%
features_High = ["Open", "Low", "Close", "Volume"]
output_var_High = pd.DataFrame(data["High"])

scaler_High = MinMaxScaler(feature_range=(0, 1))
feature_transform_High = scaler_High.fit_transform(data[features_High])
feature_transform_High = pd.DataFrame(columns=features_High, data=feature_transform_High, index=data.index)

# %%
timesplit = TimeSeriesSplit(n_splits=10)
for train_index_High, test_index_High in timesplit.split(feature_transform_High):
    X_train_High, X_test_High = feature_transform_High[:len(train_index_High)], feature_transform_High[len(train_index_High): (len(train_index_High)+len(test_index_High))]
    y_train_High, y_test_High = output_var_High[1:len(train_index_High)+1].values.ravel(), output_var_High[len(train_index_High)+1: (len(train_index_High)+len(test_index_High)+1)].values.ravel()
    X_test_High = X_test_High[:-1]

# %%
trainX_High = np.array(X_train_High)
testX_High = np.array(X_test_High)
X_train_High = trainX_High.reshape(X_train_High.shape[0], 1, X_train_High.shape[1])
X_test_High = testX_High.reshape(X_test_High.shape[0], 1, X_test_High.shape[1])

# %%
model = Sequential()
model.add(LSTM(32, input_shape=(X_train_High.shape[1], X_train_High.shape[2]), activation="relu", return_sequences=True))
model.add(LSTM(32, activation="relu"))
model.add(Dense(1))
model.compile(loss="mean_squared_error", optimizer="adam")
plot_model(model, show_shapes=True, show_layer_names=True)

# %%
save_model = 'Models/Model/Model_High.h5'
plot_model(model, show_shapes=True, show_layer_names=True)
best_model = ModelCheckpoint(save_model, monitor='loss', verbose=1, save_best_only=True, mode='auto')
model.fit(X_train_High, y_train_High, epochs=100, batch_size=8, verbose=1, callbacks=[best_model])
# Out:
# Epoch 1/100
# 396/430 [==========================>...] - ETA: 0s - loss: 2197.9697
# Epoch 1: loss improved from inf to 2081.10913, saving model to Models/Model\Model_High.h5
# 430/430 [==============================] - 3s 1ms/step - loss: 2081.1091
# Epoch 2/100
# 423/430 [============================>.] - ETA: 0s - loss: 255.1330
# Epoch 2: loss improved from 2081.10913 to 252.65565, saving model to Models/Model\Model_High.h5
# 430/430 [==============================] - 1s 1ms/step - loss: 252.6557
# Epoch 3/100
# 395/430 [==========================>...] - ETA: 0s - loss: 57.5618
# Epoch 3: loss improved from 252.65565 to 56.22408, saving model to Models/Model\Model_High.h5
# 430/430 [==============================] - 1s 1ms/step - loss: 56.2241
# Epoch 4/100
# 394/430 [==========================>...] - ETA: 0s - loss: 32.9660
# Epoch 4: loss improved from 56.22408 to 32.50379, saving model to Models/Model\Model_High.h5
# 430/430 [==============================] - 1s 1ms/step - loss: 32.5038
# Epoch 5/100
# 408/430 [===========================>..] - ETA: 0s - loss: 22.0340
# Epoch 5: loss improved from 32.50379 to 21.89927, saving model to Models/Model\Model_High.h5
# 430/430 [==============================] - 1s 1ms/step - loss: 21.8993
# Epoch 6/100
# 397/430 [==========================>...] - ETA: 0s - loss: 16.0001
# Epoch 6: loss improved from 21.89927 to 15.82261, saving model to Models/Model\Model_High.h5
# 430/430 [==============================] - 1s 1ms/step - loss: 15.8226
# Epoch 7/100
# 422/430 [============================>.] - ETA: 0s - loss: 12.0954
# Epoch 7: loss improved from 15.82261 to 12.13273, saving model to Models/Model\Model_High.h5
# 430/430 [==============================] - 1s 2ms/step - loss: 12.1327
# Epoch 8/100
# 410/430 [===========================>..] - ETA: 0s - loss: 9.7374
# Epoch 8: loss improved from 12.13273 to 9.57110, saving model to Models/Model\Model_High.h5
# 430/430 [==============================] - 1s 2ms/step - loss: 9.5711
# Epoch 9/100
# 430/430 [==============================] - ETA: 0s - loss: 7.7519
# Epoch 9: loss improved from 9.57110 to 7.75188, saving model to Models/Model\Model_High.h5
# 430/430 [==============================] - 1s 1ms/step - loss: 7.7519
# Epoch 10/100
# 414/430 [===========================>..] - ETA: 0s - loss: 6.4599
# Epoch 10: loss improved from 7.75188 to 6.39170, saving model to Models/Model\Model_High.h5
# 430/430 [==============================] - 1s 1ms/step - loss: 6.3917
# Epoch 11/100
# 394/430 [==========================>...] - ETA: 0s - loss: 5.4912
# Epoch 11: loss improved from 6.39170 to 5.37393, saving model to Models/Model\Model_High.h5
# 430/430 [==============================] - 1s 1ms/step - loss: 5.3739
# Epoch 12/100
# 426/430 [============================>.] - ETA: 0s - loss: 4.5475
# Epoch 12: loss improved from 5.37393 to 4.52884, saving model to Models/Model\Model_High.h5
# 430/430 [==============================] - 1s 1ms/step - loss: 4.5288
# Epoch 13/100
# 402/430 [===========================>..] - ETA: 0s - loss: 3.9147
# Epoch 13: loss improved from 4.52884 to 3.94540, saving model to Models/Model\Model_High.h5
# 430/430 [==============================] - 1s 2ms/step - loss: 3.9454
# Epoch 14/100
# 404/430 [===========================>..] - ETA: 0s - loss: 3.6322
# Epoch 14: loss improved from 3.94540 to 3.62193, saving model to Models/Model\Model_High.h5
# 430/430 [==============================] - 1s 2ms/step - loss: 3.6219
# Epoch 15/100
# 427/430 [============================>.] - ETA: 0s - loss: 3.4130
# Epoch 15: loss improved from 3.62193 to 3.40873, saving model to Models/Model\Model_High.h5
# 430/430 [==============================] - 1s 2ms/step - loss: 3.4087
# Epoch 16/100
# 419/430 [============================>.] - ETA: 0s - loss: 3.2348
# Epoch 16: loss improved from 3.40873 to 3.22509, saving model to Models/Model\Model_High.h5
# 430/430 [==============================] - 1s 2ms/step - loss: 3.2251
# Epoch 17/100
# 403/430 [===========================>..] - ETA: 0s - loss: 3.0374
# Epoch 17: loss improved from 3.22509 to 3.12252, saving model to Models/Model\Model_High.h5
# 430/430 [==============================] - 1s 1ms/step - loss: 3.1225
# Epoch 18/100
# 415/430 [===========================>..] - ETA: 0s - loss: 3.0958
# Epoch 18: loss improved from 3.12252 to 3.10910, saving model to Models/Model\Model_High.h5
# 430/430 [==============================] - 1s 1ms/step - loss: 3.1091
# Epoch 19/100
# 405/430 [===========================>..] - ETA: 0s - loss: 3.0705
# Epoch 19: loss improved from 3.10910 to 3.01414, saving model to Models/Model\Model_High.h5
# 430/430 [==============================] - 1s 1ms/step - loss: 3.0141
# Epoch 20/100
# 410/430 [===========================>..] - ETA: 0s - loss: 3.0683
# Epoch 20: loss did not improve from 3.01414
# 430/430 [==============================] - 1s 1ms/step - loss: 3.0221
# Epoch 21/100
# 395/430 [==========================>...] - ETA: 0s - loss: 3.1108
# Epoch 21: loss did not improve from 3.01414
# 430/430 [==============================] - 1s 1ms/step - loss: 3.0201
# Epoch 22/100
# 404/430 [===========================>..] - ETA: 0s - loss: 2.9150
# Epoch 22: loss improved from 3.01414 to 2.96629, saving model to Models/Model\Model_High.h5
# 430/430 [==============================] - 1s 1ms/step - loss: 2.9663
# Epoch 23/100
# 422/430 [============================>.] - ETA: 0s - loss: 2.8466
# Epoch 23: loss improved from 2.96629 to 2.85909, saving model to Models/Model\Model_High.h5
# 430/430 [==============================] - 1s 1ms/step - loss: 2.8591
# Epoch 24/100
# 419/430 [============================>.] - ETA: 0s - loss: 2.8478
# Epoch 24: loss improved from 2.85909 to 2.80540, saving model to Models/Model\Model_High.h5
# 430/430 [==============================] - 1s 2ms/step - loss: 2.8054
# Epoch 25/100
# 393/430 [==========================>...] - ETA: 0s - loss: 2.6911
# Epoch 25: loss improved from 2.80540 to 2.68993, saving model to Models/Model\Model_High.h5
# 430/430 [==============================] - 1s 1ms/step - loss: 2.6899
# Epoch 26/100
# 415/430 [===========================>..] - ETA: 0s - loss: 2.5251
# Epoch 26: loss improved from 2.68993 to 2.56381, saving model to Models/Model\Model_High.h5
# 430/430 [==============================] - 1s 2ms/step - loss: 2.5638
# Epoch 27/100
# 420/430 [============================>.] - ETA: 0s - loss: 2.5237
# Epoch 27: loss improved from 2.56381 to 2.49385, saving model to Models/Model\Model_High.h5
# 430/430 [==============================] - 1s 2ms/step - loss: 2.4938
# Epoch 28/100
# 413/430 [===========================>..] - ETA: 0s - loss: 2.3608
# Epoch 28: loss improved from 2.49385 to 2.35439, saving model to Models/Model\Model_High.h5
# 430/430 [==============================] - 1s 1ms/step - loss: 2.3544
# Epoch 29/100
# 425/430 [============================>.] - ETA: 0s - loss: 2.2765
# Epoch 29: loss improved from 2.35439 to 2.28818, saving model to Models/Model\Model_High.h5
# 430/430 [==============================] - 1s 1ms/step - loss: 2.2882
# Epoch 30/100
# 403/430 [===========================>..] - ETA: 0s - loss: 2.2637
# Epoch 30: loss improved from 2.28818 to 2.22247, saving model to Models/Model\Model_High.h5
# 430/430 [==============================] - 1s 1ms/step - loss: 2.2225
# Epoch 31/100
# 396/430 [==========================>...] - ETA: 0s - loss: 2.2149
# Epoch 31: loss improved from 2.22247 to 2.14296, saving model to Models/Model\Model_High.h5
# 430/430 [==============================] - 1s 1ms/step - loss: 2.1430
# Epoch 32/100
# 418/430 [============================>.] - ETA: 0s - loss: 2.1690
# Epoch 32: loss did not improve from 2.14296
# 430/430 [==============================] - 1s 2ms/step - loss: 2.1548
# Epoch 33/100
# 399/430 [==========================>...] - ETA: 0s - loss: 2.0193
# Epoch 33: loss improved from 2.14296 to 2.05202, saving model to Models/Model\Model_High.h5
# 430/430 [==============================] - 1s 2ms/step - loss: 2.0520
# Epoch 34/100
# 399/430 [==========================>...] - ETA: 0s - loss: 2.0250
# Epoch 34: loss improved from 2.05202 to 1.98640, saving model to Models/Model\Model_High.h5
# 430/430 [==============================] - 1s 2ms/step - loss: 1.9864
# Epoch 35/100
# 426/430 [============================>.] - ETA: 0s - loss: 1.9483
# Epoch 35: loss improved from 1.98640 to 1.93857, saving model to Models/Model\Model_High.h5
# 430/430 [==============================] - 1s 2ms/step - loss: 1.9386
# Epoch 36/100
# 409/430 [===========================>..] - ETA: 0s - loss: 1.7749
# Epoch 36: loss improved from 1.93857 to 1.92896, saving model to Models/Model\Model_High.h5
# 430/430 [==============================] - 1s 2ms/step - loss: 1.9290
# Epoch 37/100
# 411/430 [===========================>..] - ETA: 0s - loss: 1.9134
# Epoch 37: loss improved from 1.92896 to 1.90009, saving model to Models/Model\Model_High.h5
# 430/430 [==============================] - 1s 2ms/step - loss: 1.9001
# Epoch 38/100
# 408/430 [===========================>..] - ETA: 0s - loss: 1.8764
# Epoch 38: loss improved from 1.90009 to 1.89434, saving model to Models/Model\Model_High.h5
# 430/430 [==============================] - 1s 2ms/step - loss: 1.8943
# Epoch 39/100
# 404/430 [===========================>..] - ETA: 0s - loss: 1.9282
# Epoch 39: loss improved from 1.89434 to 1.88259, saving model to Models/Model\Model_High.h5
# 430/430 [==============================] - 1s 1ms/step - loss: 1.8826
# Epoch 40/100
# 419/430 [============================>.] - ETA: 0s - loss: 1.8850
# Epoch 40: loss did not improve from 1.88259
# 430/430 [==============================] - 1s 1ms/step - loss: 1.8908
# Epoch 41/100
# 426/430 [============================>.] - ETA: 0s - loss: 1.8399
# Epoch 41: loss improved from 1.88259 to 1.83246, saving model to Models/Model\Model_High.h5
# 430/430 [==============================] - 1s 2ms/step - loss: 1.8325
# Epoch 42/100
# 421/430 [============================>.] - ETA: 0s - loss: 1.8292
# Epoch 42: loss improved from 1.83246 to 1.82622, saving model to Models/Model\Model_High.h5
# 430/430 [==============================] - 1s 1ms/step - loss: 1.8262
# Epoch 43/100
# 417/430 [============================>.] - ETA: 0s - loss: 1.8597
# Epoch 43: loss did not improve from 1.82622
# 430/430 [==============================] - 1s 1ms/step - loss: 1.9230
# Epoch 44/100
# 404/430 [===========================>..] - ETA: 0s - loss: 1.8533
# Epoch 44: loss did not improve from 1.82622
# 430/430 [==============================] - 1s 2ms/step - loss: 1.8739
# Epoch 45/100
# 430/430 [==============================] - ETA: 0s - loss: 1.8478
# Epoch 45: loss did not improve from 1.82622
# 430/430 [==============================] - 1s 2ms/step - loss: 1.8478
# Epoch 46/100
# 394/430 [==========================>...] - ETA: 0s - loss: 1.8189
# Epoch 46: loss did not improve from 1.82622
# 430/430 [==============================] - 1s 1ms/step - loss: 1.8315
# Epoch 47/100
# 397/430 [==========================>...] - ETA: 0s - loss: 1.8299
# Epoch 47: loss improved from 1.82622 to 1.81592, saving model to Models/Model\Model_High.h5
# 430/430 [==============================] - 1s 1ms/step - loss: 1.8159
# Epoch 48/100
# 389/430 [==========================>...] - ETA: 0s - loss: 1.7538
# Epoch 48: loss improved from 1.81592 to 1.79866, saving model to Models/Model\Model_High.h5
# 430/430 [==============================] - 1s 1ms/step - loss: 1.7987
# Epoch 49/100
# 411/430 [===========================>..] - ETA: 0s - loss: 1.7590
# Epoch 49: loss improved from 1.79866 to 1.77962, saving model to Models/Model\Model_High.h5
# 430/430 [==============================] - 1s 2ms/step - loss: 1.7796
# Epoch 50/100
# 406/430 [===========================>..] - ETA: 0s - loss: 1.8946
# Epoch 50: loss did not improve from 1.77962
# 430/430 [==============================] - 1s 1ms/step - loss: 1.8578
# Epoch 51/100
# 422/430 [============================>.] - ETA: 0s - loss: 1.8057
# Epoch 51: loss did not improve from 1.77962
# 430/430 [==============================] - 1s 1ms/step - loss: 1.7968
# Epoch 52/100
# 414/430 [===========================>..] - ETA: 0s - loss: 1.7895
# Epoch 52: loss did not improve from 1.77962
# 430/430 [==============================] - 1s 1ms/step - loss: 1.8155
# Epoch 53/100
# 424/430 [============================>.] - ETA: 0s - loss: 1.8207
# Epoch 53: loss did not improve from 1.77962
# 430/430 [==============================] - 1s 2ms/step - loss: 1.8205
# Epoch 54/100
# 429/430 [============================>.] - ETA: 0s - loss: 1.8104
# Epoch 54: loss did not improve from 1.77962
# 430/430 [==============================] - 1s 2ms/step - loss: 1.8100
# Epoch 55/100
# 419/430 [============================>.] - ETA: 0s - loss: 1.8179
# Epoch 55: loss did not improve from 1.77962
# 430/430 [==============================] - 1s 2ms/step - loss: 1.8097
# Epoch 56/100
# 408/430 [===========================>..] - ETA: 0s - loss: 1.8087
# Epoch 56: loss did not improve from 1.77962
# 430/430 [==============================] - 1s 2ms/step - loss: 1.7833
# Epoch 57/100
# 419/430 [============================>.] - ETA: 0s - loss: 1.9060
# Epoch 57: loss did not improve from 1.77962
# 430/430 [==============================] - 1s 2ms/step - loss: 1.8772
# Epoch 58/100
# 430/430 [==============================] - ETA: 0s - loss: 1.8658
# Epoch 58: loss did not improve from 1.77962
# 430/430 [==============================] - 1s 2ms/step - loss: 1.8658
# Epoch 59/100
# 421/430 [============================>.] - ETA: 0s - loss: 1.8361
# Epoch 59: loss did not improve from 1.77962
# 430/430 [==============================] - 1s 2ms/step - loss: 1.8196
# Epoch 60/100
# 416/430 [============================>.] - ETA: 0s - loss: 1.8188
# Epoch 60: loss did not improve from 1.77962
# 430/430 [==============================] - 1s 2ms/step - loss: 1.8006
# Epoch 61/100
# 411/430 [===========================>..] - ETA: 0s - loss: 1.8450
# Epoch 61: loss did not improve from 1.77962
# 430/430 [==============================] - 1s 2ms/step - loss: 1.7942
# Epoch 62/100
# 403/430 [===========================>..] - ETA: 0s - loss: 1.8533
# Epoch 62: loss did not improve from 1.77962
# 430/430 [==============================] - 1s 2ms/step - loss: 1.8310
# Epoch 63/100
# 417/430 [============================>.] - ETA: 0s - loss: 1.8256
# Epoch 63: loss did not improve from 1.77962
# 430/430 [==============================] - 1s 2ms/step - loss: 1.7960
# Epoch 64/100
# 402/430 [===========================>..] - ETA: 0s - loss: 1.8040
# Epoch 64: loss did not improve from 1.77962
# 430/430 [==============================] - 1s 2ms/step - loss: 1.7835
# Epoch 65/100
# 414/430 [===========================>..] - ETA: 0s - loss: 1.7354
# Epoch 65: loss improved from 1.77962 to 1.75748, saving model to Models/Model\Model_High.h5
# 430/430 [==============================] - 1s 2ms/step - loss: 1.7575
# Epoch 66/100
# 430/430 [==============================] - ETA: 0s - loss: 1.8125
# Epoch 66: loss did not improve from 1.75748
# 430/430 [==============================] - 1s 2ms/step - loss: 1.8125
# Epoch 67/100
# 426/430 [============================>.] - ETA: 0s - loss: 1.7757
# Epoch 67: loss did not improve from 1.75748
# 430/430 [==============================] - 1s 2ms/step - loss: 1.7712
# Epoch 68/100
# 418/430 [============================>.] - ETA: 0s - loss: 1.7660
# Epoch 68: loss did not improve from 1.75748
# 430/430 [==============================] - 1s 2ms/step - loss: 1.7739
# Epoch 69/100
# 407/430 [===========================>..] - ETA: 0s - loss: 1.7262
# Epoch 69: loss did not improve from 1.75748
# 430/430 [==============================] - 1s 2ms/step - loss: 1.8105
# Epoch 70/100
# 405/430 [===========================>..] - ETA: 0s - loss: 1.7120
# Epoch 70: loss did not improve from 1.75748
# 430/430 [==============================] - 1s 2ms/step - loss: 1.7935
# Epoch 71/100
# 421/430 [============================>.] - ETA: 0s - loss: 1.8345
# Epoch 71: loss did not improve from 1.75748
# 430/430 [==============================] - 1s 2ms/step - loss: 1.8244
# Epoch 72/100
# 417/430 [============================>.] - ETA: 0s - loss: 1.7622
# Epoch 72: loss did not improve from 1.75748
# 430/430 [==============================] - 1s 2ms/step - loss: 1.7710
# Epoch 73/100
# 428/430 [============================>.] - ETA: 0s - loss: 1.7597
# Epoch 73: loss did not improve from 1.75748
# 430/430 [==============================] - 1s 2ms/step - loss: 1.7585
# Epoch 74/100
# 417/430 [============================>.] - ETA: 0s - loss: 1.7534
# Epoch 74: loss did not improve from 1.75748
# 430/430 [==============================] - 1s 2ms/step - loss: 1.7880
# Epoch 75/100
# 418/430 [============================>.] - ETA: 0s - loss: 1.7744
# Epoch 75: loss improved from 1.75748 to 1.75600, saving model to Models/Model\Model_High.h5
# 430/430 [==============================] - 1s 2ms/step - loss: 1.7560
# Epoch 76/100
# 408/430 [===========================>..] - ETA: 0s - loss: 1.8428
# Epoch 76: loss did not improve from 1.75600
# 430/430 [==============================] - 1s 2ms/step - loss: 1.7973
# Epoch 77/100
# 421/430 [============================>.] - ETA: 0s - loss: 1.8135
# Epoch 77: loss did not improve from 1.75600
# 430/430 [==============================] - 1s 2ms/step - loss: 1.7913
# Epoch 78/100
# 397/430 [==========================>...] - ETA: 0s - loss: 1.7088
# Epoch 78: loss did not improve from 1.75600
# 430/430 [==============================] - 1s 2ms/step - loss: 1.7765
# Epoch 79/100
# 429/430 [============================>.] - ETA: 0s - loss: 1.7393
# Epoch 79: loss improved from 1.75600 to 1.73884, saving model to Models/Model\Model_High.h5
# 430/430 [==============================] - 1s 2ms/step - loss: 1.7388
# Epoch 80/100
# 427/430 [============================>.] - ETA: 0s - loss: 1.7474
# Epoch 80: loss did not improve from 1.73884
# 430/430 [==============================] - 1s 2ms/step - loss: 1.7520
# Epoch 81/100
# 411/430 [===========================>..] - ETA: 0s - loss: 1.6765
# Epoch 81: loss did not improve from 1.73884
# 430/430 [==============================] - 1s 2ms/step - loss: 1.7453
# Epoch 82/100
# 415/430 [===========================>..] - ETA: 0s - loss: 1.7818
# Epoch 82: loss did not improve from 1.73884
# 430/430 [==============================] - 1s 2ms/step - loss: 1.8235
# Epoch 83/100
# 426/430 [============================>.] - ETA: 0s - loss: 1.7544
# Epoch 83: loss did not improve from 1.73884
# 430/430 [==============================] - 1s 2ms/step - loss: 1.7489
# Epoch 84/100
# 413/430 [===========================>..] - ETA: 0s - loss: 1.7930
# Epoch 84: loss did not improve from 1.73884
# 430/430 [==============================] - 1s 2ms/step - loss: 1.7717
# Epoch 85/100
# 404/430 [===========================>..] - ETA: 0s - loss: 1.7646
# Epoch 85: loss improved from 1.73884 to 1.73538, saving model to Models/Model\Model_High.h5
# 430/430 [==============================] - 1s 2ms/step - loss: 1.7354
# Epoch 86/100
# 425/430 [============================>.] - ETA: 0s - loss: 1.7289
# Epoch 86: loss improved from 1.73538 to 1.71895, saving model to Models/Model\Model_High.h5
# 430/430 [==============================] - 1s 2ms/step - loss: 1.7190
# Epoch 87/100
# 426/430 [============================>.] - ETA: 0s - loss: 1.7742
# Epoch 87: loss did not improve from 1.71895
# 430/430 [==============================] - 1s 2ms/step - loss: 1.7761
# Epoch 88/100
# 423/430 [============================>.] - ETA: 0s - loss: 1.7706
# Epoch 88: loss did not improve from 1.71895
# 430/430 [==============================] - 1s 2ms/step - loss: 1.7551
# Epoch 89/100
# 424/430 [============================>.] - ETA: 0s - loss: 1.8089
# Epoch 89: loss did not improve from 1.71895
# 430/430 [==============================] - 1s 2ms/step - loss: 1.7923
# Epoch 90/100
# 422/430 [============================>.] - ETA: 0s - loss: 1.7929
# Epoch 90: loss did not improve from 1.71895
# 430/430 [==============================] - 1s 2ms/step - loss: 1.7825
# Epoch 91/100
# 417/430 [============================>.] - ETA: 0s - loss: 1.7650
# Epoch 91: loss did not improve from 1.71895
# 430/430 [==============================] - 1s 2ms/step - loss: 1.7371
# Epoch 92/100
# 413/430 [===========================>..] - ETA: 0s - loss: 1.7330
# Epoch 92: loss did not improve from 1.71895
# 430/430 [==============================] - 1s 2ms/step - loss: 1.7617
# Epoch 93/100
# 417/430 [============================>.] - ETA: 0s - loss: 1.7144
# Epoch 93: loss did not improve from 1.71895
# 430/430 [==============================] - 1s 2ms/step - loss: 1.7646
# Epoch 94/100
# 408/430 [===========================>..] - ETA: 0s - loss: 1.8260
# Epoch 94: loss did not improve from 1.71895
# 430/430 [==============================] - 1s 2ms/step - loss: 1.7933
# Epoch 95/100
# 422/430 [============================>.] - ETA: 0s - loss: 1.7338
# Epoch 95: loss did not improve from 1.71895
# 430/430 [==============================] - 1s 2ms/step - loss: 1.7273
# Epoch 96/100
# 418/430 [============================>.] - ETA: 0s - loss: 1.7233
# Epoch 96: loss did not improve from 1.71895
# 430/430 [==============================] - 1s 2ms/step - loss: 1.7192
# Epoch 97/100
# 426/430 [============================>.] - ETA: 0s - loss: 1.7602
# Epoch 97: loss did not improve from 1.71895
# 430/430 [==============================] - 1s 2ms/step - loss: 1.7560
# Epoch 98/100
# 406/430 [===========================>..] - ETA: 0s - loss: 1.7258
# Epoch 98: loss did not improve from 1.71895
# 430/430 [==============================] - 1s 2ms/step - loss: 1.7265
# Epoch 99/100
# 422/430 [============================>.] - ETA: 0s - loss: 1.7499
# Epoch 99: loss did not improve from 1.71895
# 430/430 [==============================] - 1s 2ms/step - loss: 1.7303
# Epoch 100/100
# 426/430 [============================>.] - ETA: 0s - loss: 1.7621
# Epoch 100: loss did not improve from 1.71895
# 430/430 [==============================] - 1s 2ms/step - loss: 1.7539

# %%
with open('Models/scaler/scaler_High.pkl', 'wb') as file:
    pickle.dump(scaler_High, file)

# %%
loss = model.evaluate(X_test_High, y_test_High, verbose=0)
print("Kết quả (MSE):", loss)
y_pred_High = model.predict(X_test_High)
r2 = r2_score(y_test_High, y_pred_High)
mae = mean_absolute_error(y_test_High, y_pred_High)
mape = mean_absolute_percentage_error(y_test_High, y_pred_High)
print("R₂: ", r2)
print("MAE: ", mae)
print("MAPE: ", mape , "%")
plt.figure(figsize=(10, 6))
plt.plot(y_test_High, label='Actual')
plt.plot(y_pred_High, label='Predicted')
plt.title('Biểu đồ đánh giá độ chính xác của quá trình huấn luyện dự đoán giá cao nhất')
plt.legend()
plt.show()
# Out:
# Kết quả (MSE): 101.70117950439453
# 11/11 [==============================] - 0s 2ms/step
# R₂:  0.9809903788228377
# MAE:  7.4346637478127295
# MAPE:  0.023156343096453105 %

# %% [markdown]
# <li>Sử dụng thông tin dữ liệu của giá 'Open', 'High', 'Close' và 'Volume' để dự đoán giá 'Low'</li>

# %%
features_Low = ["Open", "High", "Close", "Volume"]
output_var_Low = pd.DataFrame(data["Low"])

scaler_Low = MinMaxScaler(feature_range=(0, 1))
feature_transform_Low = scaler_Low.fit_transform(data[features_Low])
feature_transform_Low = pd.DataFrame(columns=features_Low, data=feature_transform_Low, index=data.index)

# %%
timesplit = TimeSeriesSplit(n_splits=10)
for train_index_Low, test_index_Low in timesplit.split(feature_transform_Low):
    X_train_Low, X_test_Low = feature_transform_Low[:len(train_index_Low)], feature_transform_Low[len(train_index_Low): (len(train_index_Low)+len(test_index_Low))]
    y_train_Low, y_test_Low = output_var_Low[1:len(train_index_Low)+1].values.ravel(), output_var_Low[len(train_index_Low)+1: (len(train_index_Low)+len(test_index_Low)+1)].values.ravel()
    X_test_Low = X_test_Low[:-1]

# %%
trainX_Low = np.array(X_train_Low)
testX_Low = np.array(X_test_Low)
X_train_Low = trainX_Low.reshape(X_train_Low.shape[0], 1, X_train_Low.shape[1])
X_test_Low = testX_Low.reshape(X_test_Low.shape[0], 1, X_test_Low.shape[1])

# %%
model = Sequential()
model.add(LSTM(32, input_shape=(X_train_Low.shape[1], X_train_Low.shape[2]), activation="relu", return_sequences=True))
model.add(LSTM(32, activation="relu"))
model.add(Dense(1))
model.compile(loss="mean_squared_error", optimizer="adam")
plot_model(model, show_shapes=True, show_layer_names=True)

# %%
save_model = 'Models/Model/Model_Low.h5'
plot_model(model, show_shapes=True, show_layer_names=True)
best_model = ModelCheckpoint(save_model, monitor='loss', verbose=1, save_best_only=True, mode='auto')
model.fit(X_train_Low, y_train_Low, epochs=100, batch_size=8, verbose=1, callbacks=[best_model])
# Out:
# Epoch 1/100
# 418/430 [============================>.] - ETA: 0s - loss: 1933.5054
# Epoch 1: loss improved from inf to 1893.05273, saving model to Models/Model\Model_Low.h5
# 430/430 [==============================] - 3s 2ms/step - loss: 1893.0527
# Epoch 2/100
# 396/430 [==========================>...] - ETA: 0s - loss: 127.3389
# Epoch 2: loss improved from 1893.05273 to 119.08692, saving model to Models/Model\Model_Low.h5
# 430/430 [==============================] - 1s 2ms/step - loss: 119.0869
# Epoch 3/100
# 422/430 [============================>.] - ETA: 0s - loss: 10.4850
# Epoch 3: loss improved from 119.08692 to 10.40643, saving model to Models/Model\Model_Low.h5
# 430/430 [==============================] - 1s 2ms/step - loss: 10.4064
# Epoch 4/100
# 429/430 [============================>.] - ETA: 0s - loss: 5.0533
# Epoch 4: loss improved from 10.40643 to 5.05307, saving model to Models/Model\Model_Low.h5
# 430/430 [==============================] - 1s 2ms/step - loss: 5.0531
# Epoch 5/100
# 430/430 [==============================] - ETA: 0s - loss: 3.9417
# Epoch 5: loss improved from 5.05307 to 3.94167, saving model to Models/Model\Model_Low.h5
# 430/430 [==============================] - 1s 2ms/step - loss: 3.9417
# Epoch 6/100
# 411/430 [===========================>..] - ETA: 0s - loss: 3.5025
# Epoch 6: loss improved from 3.94167 to 3.48256, saving model to Models/Model\Model_Low.h5
# 430/430 [==============================] - 1s 2ms/step - loss: 3.4826
# Epoch 7/100
# 413/430 [===========================>..] - ETA: 0s - loss: 3.1178
# Epoch 7: loss improved from 3.48256 to 3.09318, saving model to Models/Model\Model_Low.h5
# 430/430 [==============================] - 1s 2ms/step - loss: 3.0932
# Epoch 8/100
# 409/430 [===========================>..] - ETA: 0s - loss: 2.8736
# Epoch 8: loss improved from 3.09318 to 2.81704, saving model to Models/Model\Model_Low.h5
# 430/430 [==============================] - 1s 2ms/step - loss: 2.8170
# Epoch 9/100
# 430/430 [==============================] - ETA: 0s - loss: 2.5906
# Epoch 9: loss improved from 2.81704 to 2.59057, saving model to Models/Model\Model_Low.h5
# 430/430 [==============================] - 1s 2ms/step - loss: 2.5906
# Epoch 10/100
# 403/430 [===========================>..] - ETA: 0s - loss: 2.6192
# Epoch 10: loss improved from 2.59057 to 2.52536, saving model to Models/Model\Model_Low.h5
# 430/430 [==============================] - 1s 2ms/step - loss: 2.5254
# Epoch 11/100
# 425/430 [============================>.] - ETA: 0s - loss: 2.3986
# Epoch 11: loss improved from 2.52536 to 2.41415, saving model to Models/Model\Model_Low.h5
# 430/430 [==============================] - 1s 2ms/step - loss: 2.4141
# Epoch 12/100
# 414/430 [===========================>..] - ETA: 0s - loss: 2.3594
# Epoch 12: loss improved from 2.41415 to 2.33332, saving model to Models/Model\Model_Low.h5
# 430/430 [==============================] - 1s 2ms/step - loss: 2.3333
# Epoch 13/100
# 417/430 [============================>.] - ETA: 0s - loss: 2.3238
# Epoch 13: loss improved from 2.33332 to 2.28026, saving model to Models/Model\Model_Low.h5
# 430/430 [==============================] - 1s 2ms/step - loss: 2.2803
# Epoch 14/100
# 425/430 [============================>.] - ETA: 0s - loss: 2.2149
# Epoch 14: loss improved from 2.28026 to 2.24528, saving model to Models/Model\Model_Low.h5
# 430/430 [==============================] - 1s 2ms/step - loss: 2.2453
# Epoch 15/100
# 418/430 [============================>.] - ETA: 0s - loss: 2.2408
# Epoch 15: loss did not improve from 2.24528
# 430/430 [==============================] - 1s 2ms/step - loss: 2.2485
# Epoch 16/100
# 410/430 [===========================>..] - ETA: 0s - loss: 2.2745
# Epoch 16: loss improved from 2.24528 to 2.22405, saving model to Models/Model\Model_Low.h5
# 430/430 [==============================] - 1s 2ms/step - loss: 2.2241
# Epoch 17/100
# 420/430 [============================>.] - ETA: 0s - loss: 2.1960
# Epoch 17: loss improved from 2.22405 to 2.17948, saving model to Models/Model\Model_Low.h5
# 430/430 [==============================] - 1s 2ms/step - loss: 2.1795
# Epoch 18/100
# 395/430 [==========================>...] - ETA: 0s - loss: 2.1697
# Epoch 18: loss improved from 2.17948 to 2.10785, saving model to Models/Model\Model_Low.h5
# 430/430 [==============================] - 1s 2ms/step - loss: 2.1079
# Epoch 19/100
# 415/430 [===========================>..] - ETA: 0s - loss: 2.1427
# Epoch 19: loss did not improve from 2.10785
# 430/430 [==============================] - 1s 2ms/step - loss: 2.1091
# Epoch 20/100
# 416/430 [============================>.] - ETA: 0s - loss: 2.1139
# Epoch 20: loss improved from 2.10785 to 2.08391, saving model to Models/Model\Model_Low.h5
# 430/430 [==============================] - 1s 2ms/step - loss: 2.0839
# Epoch 21/100
# 423/430 [============================>.] - ETA: 0s - loss: 2.1921
# Epoch 21: loss did not improve from 2.08391
# 430/430 [==============================] - 1s 2ms/step - loss: 2.1713
# Epoch 22/100
# 419/430 [============================>.] - ETA: 0s - loss: 2.1012
# Epoch 22: loss improved from 2.08391 to 2.07854, saving model to Models/Model\Model_Low.h5
# 430/430 [==============================] - 1s 2ms/step - loss: 2.0785
# Epoch 23/100
# 412/430 [===========================>..] - ETA: 0s - loss: 2.1315
# Epoch 23: loss did not improve from 2.07854
# 430/430 [==============================] - 1s 2ms/step - loss: 2.0950
# Epoch 24/100
# 419/430 [============================>.] - ETA: 0s - loss: 2.0311
# Epoch 24: loss improved from 2.07854 to 2.03348, saving model to Models/Model\Model_Low.h5
# 430/430 [==============================] - 1s 2ms/step - loss: 2.0335
# Epoch 25/100
# 411/430 [===========================>..] - ETA: 0s - loss: 1.9666
# Epoch 25: loss improved from 2.03348 to 1.97792, saving model to Models/Model\Model_Low.h5
# 430/430 [==============================] - 1s 2ms/step - loss: 1.9779
# Epoch 26/100
# 408/430 [===========================>..] - ETA: 0s - loss: 2.1363
# Epoch 26: loss did not improve from 1.97792
# 430/430 [==============================] - 1s 2ms/step - loss: 2.0751
# Epoch 27/100
# 406/430 [===========================>..] - ETA: 0s - loss: 1.9475
# Epoch 27: loss did not improve from 1.97792
# 430/430 [==============================] - 1s 2ms/step - loss: 2.0030
# Epoch 28/100
# 405/430 [===========================>..] - ETA: 0s - loss: 2.0830
# Epoch 28: loss did not improve from 1.97792
# 430/430 [==============================] - 1s 2ms/step - loss: 2.0312
# Epoch 29/100
# 428/430 [============================>.] - ETA: 0s - loss: 2.0197
# Epoch 29: loss did not improve from 1.97792
# 430/430 [==============================] - 1s 2ms/step - loss: 2.0148
# Epoch 30/100
# 426/430 [============================>.] - ETA: 0s - loss: 1.9901
# Epoch 30: loss did not improve from 1.97792
# 430/430 [==============================] - 1s 2ms/step - loss: 1.9900
# Epoch 31/100
# 424/430 [============================>.] - ETA: 0s - loss: 1.9687
# Epoch 31: loss did not improve from 1.97792
# 430/430 [==============================] - 1s 2ms/step - loss: 1.9840
# Epoch 32/100
# 402/430 [===========================>..] - ETA: 0s - loss: 2.0075
# Epoch 32: loss did not improve from 1.97792
# 430/430 [==============================] - 1s 2ms/step - loss: 1.9855
# Epoch 33/100
# 430/430 [==============================] - ETA: 0s - loss: 1.9960
# Epoch 33: loss did not improve from 1.97792
# 430/430 [==============================] - 1s 2ms/step - loss: 1.9960
# Epoch 34/100
# 420/430 [============================>.] - ETA: 0s - loss: 1.8585
# Epoch 34: loss improved from 1.97792 to 1.97125, saving model to Models/Model\Model_Low.h5
# 430/430 [==============================] - 1s 2ms/step - loss: 1.9712
# Epoch 35/100
# 404/430 [===========================>..] - ETA: 0s - loss: 1.9771
# Epoch 35: loss improved from 1.97125 to 1.95489, saving model to Models/Model\Model_Low.h5
# 430/430 [==============================] - 1s 2ms/step - loss: 1.9549
# Epoch 36/100
# 420/430 [============================>.] - ETA: 0s - loss: 1.9704
# Epoch 36: loss improved from 1.95489 to 1.95473, saving model to Models/Model\Model_Low.h5
# 430/430 [==============================] - 1s 2ms/step - loss: 1.9547
# Epoch 37/100
# 398/430 [==========================>...] - ETA: 0s - loss: 2.0301
# Epoch 37: loss did not improve from 1.95473
# 430/430 [==============================] - 1s 2ms/step - loss: 1.9999
# Epoch 38/100
# 412/430 [===========================>..] - ETA: 0s - loss: 1.8957
# Epoch 38: loss did not improve from 1.95473
# 430/430 [==============================] - 1s 2ms/step - loss: 2.0230
# Epoch 39/100
# 427/430 [============================>.] - ETA: 0s - loss: 1.9345
# Epoch 39: loss did not improve from 1.95473
# 430/430 [==============================] - 1s 2ms/step - loss: 1.9748
# Epoch 40/100
# 417/430 [============================>.] - ETA: 0s - loss: 1.9994
# Epoch 40: loss did not improve from 1.95473
# 430/430 [==============================] - 1s 2ms/step - loss: 1.9771
# Epoch 41/100
# 412/430 [===========================>..] - ETA: 0s - loss: 1.9832
# Epoch 41: loss did not improve from 1.95473
# 430/430 [==============================] - 1s 2ms/step - loss: 1.9624
# Epoch 42/100
# 400/430 [==========================>...] - ETA: 0s - loss: 1.9660
# Epoch 42: loss did not improve from 1.95473
# 430/430 [==============================] - 1s 2ms/step - loss: 1.9920
# Epoch 43/100
# 411/430 [===========================>..] - ETA: 0s - loss: 1.9574
# Epoch 43: loss improved from 1.95473 to 1.93829, saving model to Models/Model\Model_Low.h5
# 430/430 [==============================] - 1s 2ms/step - loss: 1.9383
# Epoch 44/100
# 420/430 [============================>.] - ETA: 0s - loss: 1.9105
# Epoch 44: loss improved from 1.93829 to 1.90630, saving model to Models/Model\Model_Low.h5
# 430/430 [==============================] - 1s 2ms/step - loss: 1.9063
# Epoch 45/100
# 402/430 [===========================>..] - ETA: 0s - loss: 1.9287
# Epoch 45: loss did not improve from 1.90630
# 430/430 [==============================] - 1s 2ms/step - loss: 1.9233
# Epoch 46/100
# 419/430 [============================>.] - ETA: 0s - loss: 1.8834
# Epoch 46: loss did not improve from 1.90630
# 430/430 [==============================] - 1s 2ms/step - loss: 1.9111
# Epoch 47/100
# 400/430 [==========================>...] - ETA: 0s - loss: 1.9337
# Epoch 47: loss did not improve from 1.90630
# 430/430 [==============================] - 1s 2ms/step - loss: 1.9152
# Epoch 48/100
# 420/430 [============================>.] - ETA: 0s - loss: 1.9480
# Epoch 48: loss did not improve from 1.90630
# 430/430 [==============================] - 1s 2ms/step - loss: 1.9280
# Epoch 49/100
# 423/430 [============================>.] - ETA: 0s - loss: 1.9583
# Epoch 49: loss did not improve from 1.90630
# 430/430 [==============================] - 1s 2ms/step - loss: 1.9366
# Epoch 50/100
# 420/430 [============================>.] - ETA: 0s - loss: 1.9372
# Epoch 50: loss did not improve from 1.90630
# 430/430 [==============================] - 1s 2ms/step - loss: 1.9474
# Epoch 51/100
# 415/430 [===========================>..] - ETA: 0s - loss: 1.8852
# Epoch 51: loss did not improve from 1.90630
# 430/430 [==============================] - 1s 2ms/step - loss: 1.9266
# Epoch 52/100
# 426/430 [============================>.] - ETA: 0s - loss: 1.9877
# Epoch 52: loss did not improve from 1.90630
# 430/430 [==============================] - 1s 2ms/step - loss: 1.9772
# Epoch 53/100
# 405/430 [===========================>..] - ETA: 0s - loss: 1.8528
# Epoch 53: loss did not improve from 1.90630
# 430/430 [==============================] - 1s 2ms/step - loss: 1.9258
# Epoch 54/100
# 420/430 [============================>.] - ETA: 0s - loss: 1.9504
# Epoch 54: loss did not improve from 1.90630
# 430/430 [==============================] - 1s 2ms/step - loss: 1.9355
# Epoch 55/100
# 425/430 [============================>.] - ETA: 0s - loss: 1.9333
# Epoch 55: loss did not improve from 1.90630
# 430/430 [==============================] - 1s 2ms/step - loss: 1.9237
# Epoch 56/100
# 429/430 [============================>.] - ETA: 0s - loss: 1.9652
# Epoch 56: loss did not improve from 1.90630
# 430/430 [==============================] - 1s 2ms/step - loss: 1.9651
# Epoch 57/100
# 425/430 [============================>.] - ETA: 0s - loss: 1.8778
# Epoch 57: loss improved from 1.90630 to 1.89506, saving model to Models/Model\Model_Low.h5
# 430/430 [==============================] - 1s 2ms/step - loss: 1.8951
# Epoch 58/100
# 421/430 [============================>.] - ETA: 0s - loss: 1.9142
# Epoch 58: loss did not improve from 1.89506
# 430/430 [==============================] - 1s 2ms/step - loss: 1.9091
# Epoch 59/100
# 418/430 [============================>.] - ETA: 0s - loss: 1.9041
# Epoch 59: loss did not improve from 1.89506
# 430/430 [==============================] - 1s 2ms/step - loss: 1.9261
# Epoch 60/100
# 427/430 [============================>.] - ETA: 0s - loss: 1.9043
# Epoch 60: loss did not improve from 1.89506
# 430/430 [==============================] - 1s 2ms/step - loss: 1.9166
# Epoch 61/100
# 429/430 [============================>.] - ETA: 0s - loss: 1.8815
# Epoch 61: loss improved from 1.89506 to 1.88091, saving model to Models/Model\Model_Low.h5
# 430/430 [==============================] - 1s 2ms/step - loss: 1.8809
# Epoch 62/100
# 418/430 [============================>.] - ETA: 0s - loss: 1.9955
# Epoch 62: loss did not improve from 1.88091
# 430/430 [==============================] - 1s 2ms/step - loss: 1.9778
# Epoch 63/100
# 418/430 [============================>.] - ETA: 0s - loss: 1.8936
# Epoch 63: loss did not improve from 1.88091
# 430/430 [==============================] - 1s 2ms/step - loss: 1.9066
# Epoch 64/100
# 426/430 [============================>.] - ETA: 0s - loss: 1.8728
# Epoch 64: loss improved from 1.88091 to 1.86120, saving model to Models/Model\Model_Low.h5
# 430/430 [==============================] - 1s 2ms/step - loss: 1.8612
# Epoch 65/100
# 399/430 [==========================>...] - ETA: 0s - loss: 1.9196
# Epoch 65: loss did not improve from 1.86120
# 430/430 [==============================] - 1s 2ms/step - loss: 1.9254
# Epoch 66/100
# 405/430 [===========================>..] - ETA: 0s - loss: 1.8311
# Epoch 66: loss did not improve from 1.86120
# 430/430 [==============================] - 1s 2ms/step - loss: 1.9320
# Epoch 67/100
# 412/430 [===========================>..] - ETA: 0s - loss: 1.9927
# Epoch 67: loss did not improve from 1.86120
# 430/430 [==============================] - 1s 2ms/step - loss: 1.9650
# Epoch 68/100
# 411/430 [===========================>..] - ETA: 0s - loss: 1.9628
# Epoch 68: loss did not improve from 1.86120
# 430/430 [==============================] - 1s 2ms/step - loss: 1.9264
# Epoch 69/100
# 420/430 [============================>.] - ETA: 0s - loss: 1.8984
# Epoch 69: loss did not improve from 1.86120
# 430/430 [==============================] - 1s 2ms/step - loss: 1.9347
# Epoch 70/100
# 429/430 [============================>.] - ETA: 0s - loss: 1.8826
# Epoch 70: loss did not improve from 1.86120
# 430/430 [==============================] - 1s 2ms/step - loss: 1.8820
# Epoch 71/100
# 424/430 [============================>.] - ETA: 0s - loss: 1.9392
# Epoch 71: loss did not improve from 1.86120
# 430/430 [==============================] - 1s 2ms/step - loss: 1.9275
# Epoch 72/100
# 419/430 [============================>.] - ETA: 0s - loss: 1.8762
# Epoch 72: loss did not improve from 1.86120
# 430/430 [==============================] - 1s 2ms/step - loss: 1.8999
# Epoch 73/100
# 426/430 [============================>.] - ETA: 0s - loss: 1.8932
# Epoch 73: loss did not improve from 1.86120
# 430/430 [==============================] - 1s 2ms/step - loss: 1.8838
# Epoch 74/100
# 421/430 [============================>.] - ETA: 0s - loss: 1.9010
# Epoch 74: loss did not improve from 1.86120
# 430/430 [==============================] - 1s 2ms/step - loss: 1.8748
# Epoch 75/100
# 420/430 [============================>.] - ETA: 0s - loss: 1.8390
# Epoch 75: loss did not improve from 1.86120
# 430/430 [==============================] - 1s 2ms/step - loss: 1.8614
# Epoch 76/100
# 427/430 [============================>.] - ETA: 0s - loss: 1.8750
# Epoch 76: loss did not improve from 1.86120
# 430/430 [==============================] - 1s 2ms/step - loss: 1.8666
# Epoch 77/100
# 422/430 [============================>.] - ETA: 0s - loss: 1.8798
# Epoch 77: loss did not improve from 1.86120
# 430/430 [==============================] - 1s 2ms/step - loss: 1.8686
# Epoch 78/100
# 418/430 [============================>.] - ETA: 0s - loss: 1.7563
# Epoch 78: loss improved from 1.86120 to 1.82787, saving model to Models/Model\Model_Low.h5
# 430/430 [==============================] - 1s 2ms/step - loss: 1.8279
# Epoch 79/100
# 406/430 [===========================>..] - ETA: 0s - loss: 1.8491
# Epoch 79: loss did not improve from 1.82787
# 430/430 [==============================] - 1s 2ms/step - loss: 1.8643
# Epoch 80/100
# 424/430 [============================>.] - ETA: 0s - loss: 1.8339
# Epoch 80: loss did not improve from 1.82787
# 430/430 [==============================] - 1s 2ms/step - loss: 1.8967
# Epoch 81/100
# 406/430 [===========================>..] - ETA: 0s - loss: 1.9283
# Epoch 81: loss did not improve from 1.82787
# 430/430 [==============================] - 1s 2ms/step - loss: 1.9125
# Epoch 82/100
# 424/430 [============================>.] - ETA: 0s - loss: 1.9340
# Epoch 82: loss did not improve from 1.82787
# 430/430 [==============================] - 1s 2ms/step - loss: 1.9178
# Epoch 83/100
# 411/430 [===========================>..] - ETA: 0s - loss: 1.8416
# Epoch 83: loss did not improve from 1.82787
# 430/430 [==============================] - 1s 2ms/step - loss: 1.8391
# Epoch 84/100
# 425/430 [============================>.] - ETA: 0s - loss: 1.8844
# Epoch 84: loss did not improve from 1.82787
# 430/430 [==============================] - 1s 2ms/step - loss: 1.8937
# Epoch 85/100
# 429/430 [============================>.] - ETA: 0s - loss: 1.8822
# Epoch 85: loss did not improve from 1.82787
# 430/430 [==============================] - 1s 2ms/step - loss: 1.8816
# Epoch 86/100
# 428/430 [============================>.] - ETA: 0s - loss: 1.8411
# Epoch 86: loss did not improve from 1.82787
# 430/430 [==============================] - 1s 2ms/step - loss: 1.8381
# Epoch 87/100
# 421/430 [============================>.] - ETA: 0s - loss: 1.8422
# Epoch 87: loss did not improve from 1.82787
# 430/430 [==============================] - 1s 2ms/step - loss: 1.9143
# Epoch 88/100
# 430/430 [==============================] - ETA: 0s - loss: 1.8902
# Epoch 88: loss did not improve from 1.82787
# 430/430 [==============================] - 1s 2ms/step - loss: 1.8902
# Epoch 89/100
# 407/430 [===========================>..] - ETA: 0s - loss: 1.8911
# Epoch 89: loss did not improve from 1.82787
# 430/430 [==============================] - 1s 2ms/step - loss: 1.8884
# Epoch 90/100
# 420/430 [============================>.] - ETA: 0s - loss: 1.8241
# Epoch 90: loss did not improve from 1.82787
# 430/430 [==============================] - 1s 2ms/step - loss: 1.8612
# Epoch 91/100
# 406/430 [===========================>..] - ETA: 0s - loss: 1.8777
# Epoch 91: loss improved from 1.82787 to 1.81826, saving model to Models/Model\Model_Low.h5
# 430/430 [==============================] - 1s 2ms/step - loss: 1.8183
# Epoch 92/100
# 416/430 [============================>.] - ETA: 0s - loss: 1.8787
# Epoch 92: loss did not improve from 1.81826
# 430/430 [==============================] - 1s 2ms/step - loss: 1.8467
# Epoch 93/100
# 419/430 [============================>.] - ETA: 0s - loss: 1.8869
# Epoch 93: loss did not improve from 1.81826
# 430/430 [==============================] - 1s 2ms/step - loss: 1.8832
# Epoch 94/100
# 430/430 [==============================] - ETA: 0s - loss: 1.8404
# Epoch 94: loss did not improve from 1.81826
# 430/430 [==============================] - 1s 2ms/step - loss: 1.8404
# Epoch 95/100
# 406/430 [===========================>..] - ETA: 0s - loss: 1.8718
# Epoch 95: loss did not improve from 1.81826
# 430/430 [==============================] - 1s 1ms/step - loss: 1.8607
# Epoch 96/100
# 417/430 [============================>.] - ETA: 0s - loss: 1.9067
# Epoch 96: loss did not improve from 1.81826
# 430/430 [==============================] - 1s 2ms/step - loss: 1.8667
# Epoch 97/100
# 393/430 [==========================>...] - ETA: 0s - loss: 1.7696
# Epoch 97: loss did not improve from 1.81826
# 430/430 [==============================] - 1s 1ms/step - loss: 1.8687
# Epoch 98/100
# 423/430 [============================>.] - ETA: 0s - loss: 1.8750
# Epoch 98: loss did not improve from 1.81826
# 430/430 [==============================] - 1s 2ms/step - loss: 1.8910
# Epoch 99/100
# 414/430 [===========================>..] - ETA: 0s - loss: 1.7908
# Epoch 99: loss did not improve from 1.81826
# 430/430 [==============================] - 1s 1ms/step - loss: 1.8480
# Epoch 100/100
# 428/430 [============================>.] - ETA: 0s - loss: 1.8583
# Epoch 100: loss did not improve from 1.81826
# 430/430 [==============================] - 1s 1ms/step - loss: 1.8554

# %%
with open('Models/scaler/scaler_Low.pkl', 'wb') as file:
    pickle.dump(scaler_Low, file)

# %%
loss = model.evaluate(X_test_Low, y_test_Low, verbose=0)
print("Kết quả (MSE):", loss)
y_pred_Low = model.predict(X_test_Low)
r2 = r2_score(y_test_Low, y_pred_Low)
mae = mean_absolute_error(y_test_Low, y_pred_Low)
mape = mean_absolute_percentage_error(y_test_Low, y_pred_Low)
print("R₂: ", r2)
print("MAE: ", mae)
print("MAPE: ", mape , "%")
plt.figure(figsize=(10, 6))
plt.plot(y_test_Low, label='Actual')
plt.plot(y_pred_Low, label='Predicted')
plt.title('Biểu đồ đánh giá độ chính xác của quá trình huấn luyện dự đoán giá thấp nhất')
plt.legend()
plt.show()
# Out:
# Kết quả (MSE): 288.60595703125
# 11/11 [==============================] - 1s 1ms/step
# R₂:  0.9414301526745038
# MAE:  12.700043963830067
# MAPE:  0.04078019574614818 %

# %% [markdown]
# <li>Sử dụng thông tin dữ liệu của giá 'Open', 'High', 'Low' và 'Volume' để dự đoán giá 'Close'</li>

# %%
features_Close = ["Open", "High", "Low", "Volume"]
output_var_Close = pd.DataFrame(data["Close"])

scaler_Close = MinMaxScaler(feature_range=(0, 1))
feature_transform_Close = scaler_Close.fit_transform(data[features_Close])
feature_transform_Close = pd.DataFrame(columns=features_Close, data=feature_transform_Close, index=data.index)

# %%
timesplit = TimeSeriesSplit(n_splits=10)
for train_index_Close, test_index_Close in timesplit.split(feature_transform_Close):
    X_train_Close, X_test_Close = feature_transform_Close[:len(train_index_Close)], feature_transform_Close[len(train_index_Close): (len(train_index_Close)+len(test_index_Close))]
    y_train_Close, y_test_Close = output_var_Close[1:len(train_index_Close)+1].values.ravel(), output_var_Close[len(train_index_Close)+1: (len(train_index_Close)+len(test_index_Close)+1)].values.ravel()
    X_test_Close = X_test_Close[:-1]

# %%
trainX_Close = np.array(X_train_Close)
testX_Close = np.array(X_test_Close)
X_train_Close = trainX_Close.reshape(X_train_Close.shape[0], 1, X_train_Close.shape[1])
X_test_Close = testX_Close.reshape(X_test_Close.shape[0], 1, X_test_Close.shape[1])

# %%
model = Sequential()
model.add(LSTM(32, input_shape=(X_train_Close.shape[1], X_train_Close.shape[2]), activation="relu", return_sequences=True))
model.add(LSTM(32, activation="relu"))
model.add(Dense(1))
model.compile(loss="mean_squared_error", optimizer="adam")
plot_model(model, show_shapes=True, show_layer_names=True)

# %%
save_model = 'Models/Model/Model_Close.h5'
plot_model(model, show_shapes=True, show_layer_names=True)
best_model = ModelCheckpoint(save_model, monitor='loss', verbose=1, save_best_only=True, mode='auto')
model.fit(X_train_Close, y_train_Close, epochs=100, batch_size=8, verbose=1, callbacks=[best_model])
# Out:
# Epoch 1/100
# 394/430 [==========================>...] - ETA: 0s - loss: 2022.3639
# Epoch 1: loss improved from inf to 1909.36169, saving model to Models/Model\Model_Close.h5
# 430/430 [==============================] - 2s 1ms/step - loss: 1909.3617
# Epoch 2/100
# 425/430 [============================>.] - ETA: 0s - loss: 213.3216
# Epoch 2: loss improved from 1909.36169 to 211.83226, saving model to Models/Model\Model_Close.h5
# 430/430 [==============================] - 1s 1ms/step - loss: 211.8323
# Epoch 3/100
# 396/430 [==========================>...] - ETA: 0s - loss: 52.7188
# Epoch 3: loss improved from 211.83226 to 51.90714, saving model to Models/Model\Model_Close.h5
# 430/430 [==============================] - 1s 2ms/step - loss: 51.9071
# Epoch 4/100
# 407/430 [===========================>..] - ETA: 0s - loss: 29.6308
# Epoch 4: loss improved from 51.90714 to 29.26869, saving model to Models/Model\Model_Close.h5
# 430/430 [==============================] - 1s 1ms/step - loss: 29.2687
# Epoch 5/100
# 396/430 [==========================>...] - ETA: 0s - loss: 17.9311
# Epoch 5: loss improved from 29.26869 to 17.71984, saving model to Models/Model\Model_Close.h5
# 430/430 [==============================] - 1s 1ms/step - loss: 17.7198
# Epoch 6/100
# 401/430 [==========================>...] - ETA: 0s - loss: 11.8034
# Epoch 6: loss improved from 17.71984 to 11.80960, saving model to Models/Model\Model_Close.h5
# 430/430 [==============================] - 1s 1ms/step - loss: 11.8096
# Epoch 7/100
# 416/430 [============================>.] - ETA: 0s - loss: 8.3947
# Epoch 7: loss improved from 11.80960 to 8.40738, saving model to Models/Model\Model_Close.h5
# 430/430 [==============================] - 1s 1ms/step - loss: 8.4074
# Epoch 8/100
# 412/430 [===========================>..] - ETA: 0s - loss: 6.8271
# Epoch 8: loss improved from 8.40738 to 6.75044, saving model to Models/Model\Model_Close.h5
# 430/430 [==============================] - 1s 1ms/step - loss: 6.7504
# Epoch 9/100
# 406/430 [===========================>..] - ETA: 0s - loss: 5.3146
# Epoch 9: loss improved from 6.75044 to 5.22197, saving model to Models/Model\Model_Close.h5
# 430/430 [==============================] - 1s 1ms/step - loss: 5.2220
# Epoch 10/100
# 392/430 [==========================>...] - ETA: 0s - loss: 4.4752
# Epoch 10: loss improved from 5.22197 to 4.38605, saving model to Models/Model\Model_Close.h5
# 430/430 [==============================] - 1s 2ms/step - loss: 4.3861
# Epoch 11/100
# 409/430 [===========================>..] - ETA: 0s - loss: 3.8564
# Epoch 11: loss improved from 4.38605 to 3.86569, saving model to Models/Model\Model_Close.h5
# 430/430 [==============================] - 1s 1ms/step - loss: 3.8657
# Epoch 12/100
# 416/430 [============================>.] - ETA: 0s - loss: 3.5620
# Epoch 12: loss improved from 3.86569 to 3.50984, saving model to Models/Model\Model_Close.h5
# 430/430 [==============================] - 1s 1ms/step - loss: 3.5098
# Epoch 13/100
# 409/430 [===========================>..] - ETA: 0s - loss: 3.2323
# Epoch 13: loss improved from 3.50984 to 3.36242, saving model to Models/Model\Model_Close.h5
# 430/430 [==============================] - 1s 1ms/step - loss: 3.3624
# Epoch 14/100
# 429/430 [============================>.] - ETA: 0s - loss: 3.2973
# Epoch 14: loss improved from 3.36242 to 3.30753, saving model to Models/Model\Model_Close.h5
# 430/430 [==============================] - 1s 2ms/step - loss: 3.3075
# Epoch 15/100
# 405/430 [===========================>..] - ETA: 0s - loss: 3.2985
# Epoch 15: loss improved from 3.30753 to 3.22508, saving model to Models/Model\Model_Close.h5
# 430/430 [==============================] - 1s 2ms/step - loss: 3.2251
# Epoch 16/100
# 407/430 [===========================>..] - ETA: 0s - loss: 3.1982
# Epoch 16: loss improved from 3.22508 to 3.17772, saving model to Models/Model\Model_Close.h5
# 430/430 [==============================] - 1s 1ms/step - loss: 3.1777
# Epoch 17/100
# 412/430 [===========================>..] - ETA: 0s - loss: 3.0742
# Epoch 17: loss did not improve from 3.17772
# 430/430 [==============================] - 1s 1ms/step - loss: 3.1944
# Epoch 18/100
# 411/430 [===========================>..] - ETA: 0s - loss: 3.3088
# Epoch 18: loss did not improve from 3.17772
# 430/430 [==============================] - 1s 1ms/step - loss: 3.2692
# Epoch 19/100
# 413/430 [===========================>..] - ETA: 0s - loss: 3.1895
# Epoch 19: loss did not improve from 3.17772
# 430/430 [==============================] - 1s 1ms/step - loss: 3.1887
# Epoch 20/100
# 419/430 [============================>.] - ETA: 0s - loss: 3.1282
# Epoch 20: loss improved from 3.17772 to 3.13243, saving model to Models/Model\Model_Close.h5
# 430/430 [==============================] - 1s 2ms/step - loss: 3.1324
# Epoch 21/100
# 419/430 [============================>.] - ETA: 0s - loss: 3.3012
# Epoch 21: loss did not improve from 3.13243
# 430/430 [==============================] - 1s 1ms/step - loss: 3.2754
# Epoch 22/100
# 419/430 [============================>.] - ETA: 0s - loss: 3.2027
# Epoch 22: loss did not improve from 3.13243
# 430/430 [==============================] - 1s 2ms/step - loss: 3.2052
# Epoch 23/100
# 428/430 [============================>.] - ETA: 0s - loss: 3.0759
# Epoch 23: loss did not improve from 3.13243
# 430/430 [==============================] - 1s 2ms/step - loss: 3.1861
# Epoch 24/100
# 417/430 [============================>.] - ETA: 0s - loss: 3.3852
# Epoch 24: loss did not improve from 3.13243
# 430/430 [==============================] - 1s 2ms/step - loss: 3.3481
# Epoch 25/100
# 429/430 [============================>.] - ETA: 0s - loss: 3.0392
# Epoch 25: loss improved from 3.13243 to 3.03895, saving model to Models/Model\Model_Close.h5
# 430/430 [==============================] - 1s 2ms/step - loss: 3.0390
# Epoch 26/100
# 429/430 [============================>.] - ETA: 0s - loss: 3.0675
# Epoch 26: loss did not improve from 3.03895
# 430/430 [==============================] - 1s 2ms/step - loss: 3.0669
# Epoch 27/100
# 400/430 [==========================>...] - ETA: 0s - loss: 3.1243
# Epoch 27: loss did not improve from 3.03895
# 430/430 [==============================] - 1s 2ms/step - loss: 3.0715
# Epoch 28/100
# 411/430 [===========================>..] - ETA: 0s - loss: 3.1146
# Epoch 28: loss did not improve from 3.03895
# 430/430 [==============================] - 1s 2ms/step - loss: 3.0819
# Epoch 29/100
# 418/430 [============================>.] - ETA: 0s - loss: 2.9830
# Epoch 29: loss improved from 3.03895 to 2.96450, saving model to Models/Model\Model_Close.h5
# 430/430 [==============================] - 1s 2ms/step - loss: 2.9645
# Epoch 30/100
# 395/430 [==========================>...] - ETA: 0s - loss: 2.9782
# Epoch 30: loss did not improve from 2.96450
# 430/430 [==============================] - 1s 2ms/step - loss: 3.0078
# Epoch 31/100
# 406/430 [===========================>..] - ETA: 0s - loss: 3.0365
# Epoch 31: loss did not improve from 2.96450
# 430/430 [==============================] - 1s 2ms/step - loss: 2.9971
# Epoch 32/100
# 430/430 [==============================] - ETA: 0s - loss: 2.9336
# Epoch 32: loss improved from 2.96450 to 2.93360, saving model to Models/Model\Model_Close.h5
# 430/430 [==============================] - 1s 2ms/step - loss: 2.9336
# Epoch 33/100
# 414/430 [===========================>..] - ETA: 0s - loss: 2.8735
# Epoch 33: loss improved from 2.93360 to 2.84925, saving model to Models/Model\Model_Close.h5
# 430/430 [==============================] - 1s 2ms/step - loss: 2.8493
# Epoch 34/100
# 423/430 [============================>.] - ETA: 0s - loss: 2.7982
# Epoch 34: loss improved from 2.84925 to 2.80677, saving model to Models/Model\Model_Close.h5
# 430/430 [==============================] - 1s 2ms/step - loss: 2.8068
# Epoch 35/100
# 400/430 [==========================>...] - ETA: 0s - loss: 2.9208
# Epoch 35: loss did not improve from 2.80677
# 430/430 [==============================] - 1s 2ms/step - loss: 2.9339
# Epoch 36/100
# 429/430 [============================>.] - ETA: 0s - loss: 2.8630
# Epoch 36: loss did not improve from 2.80677
# 430/430 [==============================] - 1s 2ms/step - loss: 2.8765
# Epoch 37/100
# 416/430 [============================>.] - ETA: 0s - loss: 2.9159
# Epoch 37: loss did not improve from 2.80677
# 430/430 [==============================] - 1s 2ms/step - loss: 2.8660
# Epoch 38/100
# 407/430 [===========================>..] - ETA: 0s - loss: 2.9734
# Epoch 38: loss did not improve from 2.80677
# 430/430 [==============================] - 1s 2ms/step - loss: 2.9066
# Epoch 39/100
# 430/430 [==============================] - ETA: 0s - loss: 2.7953
# Epoch 39: loss improved from 2.80677 to 2.79531, saving model to Models/Model\Model_Close.h5
# 430/430 [==============================] - 1s 2ms/step - loss: 2.7953
# Epoch 40/100
# 414/430 [===========================>..] - ETA: 0s - loss: 2.9270
# Epoch 40: loss did not improve from 2.79531
# 430/430 [==============================] - 1s 2ms/step - loss: 2.8894
# Epoch 41/100
# 404/430 [===========================>..] - ETA: 0s - loss: 2.6762
# Epoch 41: loss improved from 2.79531 to 2.69690, saving model to Models/Model\Model_Close.h5
# 430/430 [==============================] - 1s 2ms/step - loss: 2.6969
# Epoch 42/100
# 408/430 [===========================>..] - ETA: 0s - loss: 2.7717
# Epoch 42: loss did not improve from 2.69690
# 430/430 [==============================] - 1s 2ms/step - loss: 2.7108
# Epoch 43/100
# 429/430 [============================>.] - ETA: 0s - loss: 2.7489
# Epoch 43: loss did not improve from 2.69690
# 430/430 [==============================] - 1s 2ms/step - loss: 2.7483
# Epoch 44/100
# 410/430 [===========================>..] - ETA: 0s - loss: 2.7559
# Epoch 44: loss did not improve from 2.69690
# 430/430 [==============================] - 1s 2ms/step - loss: 2.7202
# Epoch 45/100
# 417/430 [============================>.] - ETA: 0s - loss: 2.8142
# Epoch 45: loss did not improve from 2.69690
# 430/430 [==============================] - 1s 2ms/step - loss: 2.7546
# Epoch 46/100
# 412/430 [===========================>..] - ETA: 0s - loss: 2.7002
# Epoch 46: loss improved from 2.69690 to 2.63774, saving model to Models/Model\Model_Close.h5
# 430/430 [==============================] - 1s 2ms/step - loss: 2.6377
# Epoch 47/100
# 420/430 [============================>.] - ETA: 0s - loss: 2.7461
# Epoch 47: loss did not improve from 2.63774
# 430/430 [==============================] - 1s 2ms/step - loss: 2.7700
# Epoch 48/100
# 428/430 [============================>.] - ETA: 0s - loss: 2.6961
# Epoch 48: loss did not improve from 2.63774
# 430/430 [==============================] - 1s 2ms/step - loss: 2.6921
# Epoch 49/100
# 409/430 [===========================>..] - ETA: 0s - loss: 2.7449
# Epoch 49: loss did not improve from 2.63774
# 430/430 [==============================] - 1s 2ms/step - loss: 2.7262
# Epoch 50/100
# 430/430 [==============================] - ETA: 0s - loss: 2.6246
# Epoch 50: loss improved from 2.63774 to 2.62462, saving model to Models/Model\Model_Close.h5
# 430/430 [==============================] - 1s 2ms/step - loss: 2.6246
# Epoch 51/100
# 411/430 [===========================>..] - ETA: 0s - loss: 2.7200
# Epoch 51: loss did not improve from 2.62462
# 430/430 [==============================] - 1s 2ms/step - loss: 2.6740
# Epoch 52/100
# 429/430 [============================>.] - ETA: 0s - loss: 2.6107
# Epoch 52: loss improved from 2.62462 to 2.60991, saving model to Models/Model\Model_Close.h5
# 430/430 [==============================] - 1s 2ms/step - loss: 2.6099
# Epoch 53/100
# 406/430 [===========================>..] - ETA: 0s - loss: 2.6690
# Epoch 53: loss did not improve from 2.60991
# 430/430 [==============================] - 1s 2ms/step - loss: 2.7233
# Epoch 54/100
# 427/430 [============================>.] - ETA: 0s - loss: 2.7173
# Epoch 54: loss did not improve from 2.60991
# 430/430 [==============================] - 1s 2ms/step - loss: 2.7111
# Epoch 55/100
# 403/430 [===========================>..] - ETA: 0s - loss: 2.6452
# Epoch 55: loss did not improve from 2.60991
# 430/430 [==============================] - 1s 2ms/step - loss: 2.6173
# Epoch 56/100
# 428/430 [============================>.] - ETA: 0s - loss: 2.6431
# Epoch 56: loss did not improve from 2.60991
# 430/430 [==============================] - 1s 2ms/step - loss: 2.6481
# Epoch 57/100
# 413/430 [===========================>..] - ETA: 0s - loss: 2.7476
# Epoch 57: loss did not improve from 2.60991
# 430/430 [==============================] - 1s 2ms/step - loss: 2.6829
# Epoch 58/100
# 423/430 [============================>.] - ETA: 0s - loss: 2.5981
# Epoch 58: loss improved from 2.60991 to 2.59850, saving model to Models/Model\Model_Close.h5
# 430/430 [==============================] - 1s 2ms/step - loss: 2.5985
# Epoch 59/100
# 415/430 [===========================>..] - ETA: 0s - loss: 2.6272
# Epoch 59: loss did not improve from 2.59850
# 430/430 [==============================] - 1s 2ms/step - loss: 2.6601
# Epoch 60/100
# 430/430 [==============================] - ETA: 0s - loss: 2.7443
# Epoch 60: loss did not improve from 2.59850
# 430/430 [==============================] - 1s 2ms/step - loss: 2.7443
# Epoch 61/100
# 406/430 [===========================>..] - ETA: 0s - loss: 2.6360
# Epoch 61: loss did not improve from 2.59850
# 430/430 [==============================] - 1s 2ms/step - loss: 2.6166
# Epoch 62/100
# 429/430 [============================>.] - ETA: 0s - loss: 2.6432
# Epoch 62: loss did not improve from 2.59850
# 430/430 [==============================] - 1s 2ms/step - loss: 2.6427
# Epoch 63/100
# 407/430 [===========================>..] - ETA: 0s - loss: 2.6888
# Epoch 63: loss did not improve from 2.59850
# 430/430 [==============================] - 1s 2ms/step - loss: 2.6317
# Epoch 64/100
# 425/430 [============================>.] - ETA: 0s - loss: 2.7307
# Epoch 64: loss did not improve from 2.59850
# 430/430 [==============================] - 1s 2ms/step - loss: 2.7075
# Epoch 65/100
# 410/430 [===========================>..] - ETA: 0s - loss: 2.7521
# Epoch 65: loss did not improve from 2.59850
# 430/430 [==============================] - 1s 1ms/step - loss: 2.7002
# Epoch 66/100
# 414/430 [===========================>..] - ETA: 0s - loss: 2.6268
# Epoch 66: loss did not improve from 2.59850
# 430/430 [==============================] - 1s 2ms/step - loss: 2.6283
# Epoch 67/100
# 421/430 [============================>.] - ETA: 0s - loss: 2.6226
# Epoch 67: loss did not improve from 2.59850
# 430/430 [==============================] - 1s 2ms/step - loss: 2.6181
# Epoch 68/100
# 418/430 [============================>.] - ETA: 0s - loss: 2.6298
# Epoch 68: loss did not improve from 2.59850
# 430/430 [==============================] - 1s 2ms/step - loss: 2.6685
# Epoch 69/100
# 400/430 [==========================>...] - ETA: 0s - loss: 2.7249
# Epoch 69: loss did not improve from 2.59850
# 430/430 [==============================] - 1s 2ms/step - loss: 2.7631
# Epoch 70/100
# 426/430 [============================>.] - ETA: 0s - loss: 2.6574
# Epoch 70: loss did not improve from 2.59850
# 430/430 [==============================] - 1s 2ms/step - loss: 2.6575
# Epoch 71/100
# 420/430 [============================>.] - ETA: 0s - loss: 2.7328
# Epoch 71: loss did not improve from 2.59850
# 430/430 [==============================] - 1s 2ms/step - loss: 2.7248
# Epoch 72/100
# 403/430 [===========================>..] - ETA: 0s - loss: 2.5416
# Epoch 72: loss did not improve from 2.59850
# 430/430 [==============================] - 1s 2ms/step - loss: 2.6512
# Epoch 73/100
# 419/430 [============================>.] - ETA: 0s - loss: 2.5410
# Epoch 73: loss did not improve from 2.59850
# 430/430 [==============================] - 1s 2ms/step - loss: 2.6290
# Epoch 74/100
# 421/430 [============================>.] - ETA: 0s - loss: 2.7152
# Epoch 74: loss did not improve from 2.59850
# 430/430 [==============================] - 1s 2ms/step - loss: 2.6831
# Epoch 75/100
# 406/430 [===========================>..] - ETA: 0s - loss: 2.5746
# Epoch 75: loss improved from 2.59850 to 2.59302, saving model to Models/Model\Model_Close.h5
# 430/430 [==============================] - 1s 2ms/step - loss: 2.5930
# Epoch 76/100
# 415/430 [===========================>..] - ETA: 0s - loss: 2.7589
# Epoch 76: loss did not improve from 2.59302
# 430/430 [==============================] - 1s 2ms/step - loss: 2.7426
# Epoch 77/100
# 417/430 [============================>.] - ETA: 0s - loss: 2.7028
# Epoch 77: loss did not improve from 2.59302
# 430/430 [==============================] - 1s 2ms/step - loss: 2.7024
# Epoch 78/100
# 424/430 [============================>.] - ETA: 0s - loss: 2.6605
# Epoch 78: loss did not improve from 2.59302
# 430/430 [==============================] - 1s 2ms/step - loss: 2.6366
# Epoch 79/100
# 427/430 [============================>.] - ETA: 0s - loss: 2.5648
# Epoch 79: loss improved from 2.59302 to 2.55650, saving model to Models/Model\Model_Close.h5
# 430/430 [==============================] - 1s 2ms/step - loss: 2.5565
# Epoch 80/100
# 401/430 [==========================>...] - ETA: 0s - loss: 2.6725
# Epoch 80: loss did not improve from 2.55650
# 430/430 [==============================] - 1s 2ms/step - loss: 2.6275
# Epoch 81/100
# 429/430 [============================>.] - ETA: 0s - loss: 2.6965
# Epoch 81: loss did not improve from 2.55650
# 430/430 [==============================] - 1s 2ms/step - loss: 2.6959
# Epoch 82/100
# 402/430 [===========================>..] - ETA: 0s - loss: 2.6899
# Epoch 82: loss did not improve from 2.55650
# 430/430 [==============================] - 1s 2ms/step - loss: 2.6592
# Epoch 83/100
# 423/430 [============================>.] - ETA: 0s - loss: 2.6399
# Epoch 83: loss did not improve from 2.55650
# 430/430 [==============================] - 1s 2ms/step - loss: 2.6147
# Epoch 84/100
# 426/430 [============================>.] - ETA: 0s - loss: 2.6226
# Epoch 84: loss did not improve from 2.55650
# 430/430 [==============================] - 1s 2ms/step - loss: 2.6097
# Epoch 85/100
# 407/430 [===========================>..] - ETA: 0s - loss: 2.5797
# Epoch 85: loss did not improve from 2.55650
# 430/430 [==============================] - 1s 2ms/step - loss: 2.6417
# Epoch 86/100
# 425/430 [============================>.] - ETA: 0s - loss: 2.7163
# Epoch 86: loss did not improve from 2.55650
# 430/430 [==============================] - 1s 2ms/step - loss: 2.7084
# Epoch 87/100
# 419/430 [============================>.] - ETA: 0s - loss: 2.7564
# Epoch 87: loss did not improve from 2.55650
# 430/430 [==============================] - 1s 2ms/step - loss: 2.7677
# Epoch 88/100
# 412/430 [===========================>..] - ETA: 0s - loss: 2.6731
# Epoch 88: loss did not improve from 2.55650
# 430/430 [==============================] - 1s 2ms/step - loss: 2.6472
# Epoch 89/100
# 429/430 [============================>.] - ETA: 0s - loss: 2.6681
# Epoch 89: loss did not improve from 2.55650
# 430/430 [==============================] - 1s 2ms/step - loss: 2.6673
# Epoch 90/100
# 400/430 [==========================>...] - ETA: 0s - loss: 2.7093
# Epoch 90: loss did not improve from 2.55650
# 430/430 [==============================] - 1s 2ms/step - loss: 2.6541
# Epoch 91/100
# 430/430 [==============================] - ETA: 0s - loss: 2.5859
# Epoch 91: loss did not improve from 2.55650
# 430/430 [==============================] - 1s 2ms/step - loss: 2.5859
# Epoch 92/100
# 426/430 [============================>.] - ETA: 0s - loss: 2.6072
# Epoch 92: loss did not improve from 2.55650
# 430/430 [==============================] - 1s 2ms/step - loss: 2.5998
# Epoch 93/100
# 416/430 [============================>.] - ETA: 0s - loss: 2.5995
# Epoch 93: loss did not improve from 2.55650
# 430/430 [==============================] - 1s 2ms/step - loss: 2.5947
# Epoch 94/100
# 423/430 [============================>.] - ETA: 0s - loss: 2.7194
# Epoch 94: loss did not improve from 2.55650
# 430/430 [==============================] - 1s 2ms/step - loss: 2.7076
# Epoch 95/100
# 400/430 [==========================>...] - ETA: 0s - loss: 2.6286
# Epoch 95: loss did not improve from 2.55650
# 430/430 [==============================] - 1s 2ms/step - loss: 2.6245
# Epoch 96/100
# 427/430 [============================>.] - ETA: 0s - loss: 2.6307
# Epoch 96: loss did not improve from 2.55650
# 430/430 [==============================] - 1s 2ms/step - loss: 2.6256
# Epoch 97/100
# 428/430 [============================>.] - ETA: 0s - loss: 2.7574
# Epoch 97: loss did not improve from 2.55650
# 430/430 [==============================] - 1s 2ms/step - loss: 2.7632
# Epoch 98/100
# 427/430 [============================>.] - ETA: 0s - loss: 2.7514
# Epoch 98: loss did not improve from 2.55650
# 430/430 [==============================] - 1s 2ms/step - loss: 2.7412
# Epoch 99/100
# 402/430 [===========================>..] - ETA: 0s - loss: 2.7242
# Epoch 99: loss did not improve from 2.55650
# 430/430 [==============================] - 1s 2ms/step - loss: 2.7036
# Epoch 100/100
# 419/430 [============================>.] - ETA: 0s - loss: 2.7306
# Epoch 100: loss did not improve from 2.55650
# 430/430 [==============================] - 1s 2ms/step - loss: 2.7346

# %%
with open('Models/scaler/scaler_Close.pkl', 'wb') as file:
    pickle.dump(scaler_Close, file)

# %%
loss = model.evaluate(X_test_Close, y_test_Close, verbose=0)
print("Kết quả (MSE):", loss)
y_pred_Close = model.predict(X_test_Close)
r2 = r2_score(y_test_Close, y_pred_Close)
mae = mean_absolute_error(y_test_Close, y_pred_Close)
mape = mean_absolute_percentage_error(y_test_Close, y_pred_Close)
print("R₂: ", r2)
print("MAE: ", mae)
print("MAPE: ", mape , "%")
plt.figure(figsize=(10, 6))
plt.plot(y_test_Close, label='Actual')
plt.plot(y_pred_Close, label='Predicted')
plt.title('Biểu đồ đánh giá độ chính xác của quá trình huấn luyện dự đoán giá đóng cửa')
plt.legend()
plt.show()
# Out:
# Kết quả (MSE): 246.38388061523438
# 11/11 [==============================] - 0s 1ms/step
# R₂:  0.951952668506215
# MAE:  11.598061249620228
# MAPE:  0.0372328776238218 %

# %% [markdown]
# <h1> Bước 4:</h1> Kiểm thử kết quả của quá huấn luyện

# %%
import pandas as pd
import numpy as np
from keras.models import load_model
import pickle
features_Open_S = ["High", "Low", "Close", "Volume"]
loaded_model_Open = load_model('Models/Model/Model_Open.h5')
with open('Models/scaler/scaler_Open.pkl', 'rb') as file:
    scaler_Open_S = pickle.load(file)
high_value = float(input("Nhập giá cao nhất: "))
low_value = float(input("Nhập giá thấp nhất: "))
close_value = float(input("Nhập giá đóng cửa: "))
volume_value = float(input("Nhập khối lượng giao dịch: "))
new_features_Open = scaler_Open_S.transform([[high_value, low_value, close_value, volume_value]])
new_features_Open = pd.DataFrame(columns=features_Open_S, data=new_features_Open)
new_data_Open = np.array(new_features_Open)
new_data_Open = new_data_Open.reshape(new_data_Open.shape[0], 1, new_data_Open.shape[1])
predicted_adj_Open = loaded_model_Open.predict(new_data_Open)
predicted_adj_Open = predicted_adj_Open[0][0]
print("Kết quả (dự đoán) giá mở cửa: ", predicted_adj_Open)
# Out:
# D:\Tu_Hoc_Lap_Trinh\Python\Major_Assignment\venv\lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# 1/1 [==============================] - 1s 660ms/step
# Kết quả (dự đoán) giá mở cửa:  [[338.02493]]

# %%
import pandas as pd
import numpy as np
from keras.models import load_model
import pickle
features_High_S = ["Open", "Low", "Close", "Volume"]
loaded_model_High = load_model('Models/Model/Model_High.h5')
with open('Models/scaler/scaler_High.pkl', 'rb') as file:
    scaler_High_S = pickle.load(file)
open_value = float(input("Nhập giá mở cửa: "))
low_value = float(input("Nhập giá thấp nhất: "))
close_value = float(input("Nhập giá đóng cửa: "))
volume_value = float(input("Nhập khối lượng giao dịch: "))
new_features_High = scaler_High_S.transform([[open_value, low_value, close_value, volume_value]])
new_features_High = pd.DataFrame(columns=features_High_S, data=new_features_High)
new_data_High = np.array(new_features_High)
new_data_High = new_data_High.reshape(new_data_High.shape[0], 1, new_data_High.shape[1])
predicted_adj_High = loaded_model_High.predict(new_data_High)
predicted_adj_High = predicted_adj_High[0][0]
print("Kết quả (dự đoán) giá cao nhất: ", predicted_adj_High)
# Out:
# D:\Tu_Hoc_Lap_Trinh\Python\Major_Assignment\venv\lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# 1/1 [==============================] - 0s 272ms/step
# Kết quả (dự đoán) giá cao nhất:  [[386.56122]]

# %%
import pandas as pd
import numpy as np
from keras.models import load_model
import pickle
features_Low_S = ["Open", "High", "Close", "Volume"]
loaded_model_Low = load_model('Models/Model/Model_Low.h5')
with open('Models/scaler/scaler_Low.pkl', 'rb') as file:
    scaler_Low_S = pickle.load(file)
open_value = float(input("Hãy nhập giá mở cửa: "))
high_value = float(input("Hãy nhập giá cao nhất: "))
close_value = float(input("Hãy nhập giá đóng cửa: "))
volume_value = float(input("Hãy nhập khối lượng giao dịch: "))
new_features_Low = scaler_Low_S.transform([[open_value, high_value, close_value, volume_value]])
new_features_Low = pd.DataFrame(columns=features_Low_S, data=new_features_Low)
new_data_Low = np.array(new_features_Low)
new_data_Low = new_data_Low.reshape(new_data_Low.shape[0], 1, new_data_Low.shape[1])
predicted_adj_Low = loaded_model_Low.predict(new_data_Low)
predicted_adj_Low = predicted_adj_Low[0][0]
print("Kết quả giá thấp nhất (Dự đoán) cho ngày mai:", predicted_adj_Low)
# Out:
# D:\Tu_Hoc_Lap_Trinh\Python\Major_Assignment\venv\lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# 1/1 [==============================] - 0s 230ms/step
# Kết quả giá thấp nhất (Dự đoán) cho ngày mai: [[373.0669]]

# %%
import pandas as pd
import numpy as np
from keras.models import load_model
import pickle
loaded_model_Close = load_model('Models/Model/Model_Close.h5')
features_Close_S = ["Open", "High", "Low", "Volume"]
with open('Models/scaler/scaler_Close.pkl', 'rb') as file:
    scaler_Close_S = pickle.load(file)
open_value = float(input("Hãy nhập giá mở cửa: "))
high_value = float(input("Hãy nhập giá cao nhất: "))
low_value = float(input("Hãy nhập giá thấp nhất: "))
volume_value = float(input("Hãy nhập khối lượng giao dịch: "))
new_features_Close = scaler_Close_S.transform([[open_value, high_value, low_value, volume_value]])
new_features_Close = pd.DataFrame(columns=features_Close_S, data=new_features_Close)
new_data_Close = np.array(new_features_Close)
new_data_Close = new_data_Close.reshape(new_data_Close.shape[0], 1, new_data_Close.shape[1])
predicted_adj_close = loaded_model_Close.predict(new_data_Close)
predicted_adj_close = predicted_adj_close[0][0]
print("Kết quả giá đóng cửa (Dự đoán) cho ngày mai:", predicted_adj_close)
# Out:
# D:\Tu_Hoc_Lap_Trinh\Python\Major_Assignment\venv\lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# WARNING:tensorflow:5 out of the last 15 calls to <function Model.make_predict_function.<locals>.predict_function at 0x00000217F3338940> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has reduce_retracing=True option that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 1/1 [==============================] - 0s 183ms/step
# Kết quả giá đóng cửa (Dự đoán) cho ngày mai: 374.33093
